# %%
import pandas as pd
import glob

# %% [markdown]
# # Procesamiento de datos

# %%
resultados=pd.read_csv("data/Only_training_hipotesis_salida/resultados.csv")
resultados
# Out:
#      Unnamed: 0                                                  0  \
# 0             0  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# 1             1  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# 2             2  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# 3             3  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# 4             4  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# ..          ...                                                ...
# 116         116  data/Only_training_hipotesis\0.8\TEST_new_0.8_...
# 117         117  data/Only_training_hipotesis\0.8\TEST_new_0.8_...
# 118         118  data/Only_training_hipotesis\0.8\TEST_new_0.8_...
# 119         119  data/Only_training_hipotesis\0.8\TEST_new_0.8_...
# 120         120    data/Only_training_hipotesis\1\TEST_new_1_0.csv
#
#                                              1
# 0    [0.42894517253426945, 0.8176470588235294]
# 1     [0.4750452953226426, 0.8117647058823529]
# 2     [0.4165754416409661, 0.8514705882352941]
# 3     [0.4415535737486447, 0.8264705882352941]
# 4     [0.4969964521772721, 0.8205882352941176]
# ..                                         ...
# 116  [0.46185993282867066, 0.8291475710029672]
# 117  [0.45558229036881875, 0.8295142071056978]
# 118  [0.45798323377352257, 0.8309807516368128]
# 119   [0.4669914347113654, 0.8253895508270543]
# 120  [0.46506612251748575, 0.8271007479015098]
#
# [121 rows x 3 columns]

# %%
resultados=resultados.assign(grupo=0.0)
resultados=resultados.assign(error=0.0)
resultados=resultados.assign(accuracy=0.0)

# %%
resultados
# Out:
#      Unnamed: 0                                                  0  \
# 0             0  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# 1             1  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# 2             2  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# 3             3  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# 4             4  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# ..          ...                                                ...
# 116         116  data/Only_training_hipotesis\0.8\TEST_new_0.8_...
# 117         117  data/Only_training_hipotesis\0.8\TEST_new_0.8_...
# 118         118  data/Only_training_hipotesis\0.8\TEST_new_0.8_...
# 119         119  data/Only_training_hipotesis\0.8\TEST_new_0.8_...
# 120         120    data/Only_training_hipotesis\1\TEST_new_1_0.csv
#
#                                              1  grupo  error  accuracy
# 0    [0.42894517253426945, 0.8176470588235294]    0.0    0.0       0.0
# 1     [0.4750452953226426, 0.8117647058823529]    0.0    0.0       0.0
# 2     [0.4165754416409661, 0.8514705882352941]    0.0    0.0       0.0
# 3     [0.4415535737486447, 0.8264705882352941]    0.0    0.0       0.0
# 4     [0.4969964521772721, 0.8205882352941176]    0.0    0.0       0.0
# ..                                         ...    ...    ...       ...
# 116  [0.46185993282867066, 0.8291475710029672]    0.0    0.0       0.0
# 117  [0.45558229036881875, 0.8295142071056978]    0.0    0.0       0.0
# 118  [0.45798323377352257, 0.8309807516368128]    0.0    0.0       0.0
# 119   [0.4669914347113654, 0.8253895508270543]    0.0    0.0       0.0
# 120  [0.46506612251748575, 0.8271007479015098]    0.0    0.0       0.0
#
# [121 rows x 6 columns]

# %%
temp=resultados.copy()
for index,strings in temp.iterrows():
    resultados.at[index,'grupo']=float(strings[1].split('_')[4])*100
    resultados.at[index,'error']=float(strings[2].split(',')[0][1:])
    resultados.at[index,'accuracy']=float(strings[2].split(',')[1][:-1])
resultados
# Out:
#      Unnamed: 0                                                  0  \
# 0             0  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# 1             1  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# 2             2  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# 3             3  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# 4             4  data/Only_training_hipotesis\0.05\TEST_new_0.0...
# ..          ...                                                ...
# 116         116  data/Only_training_hipotesis\0.8\TEST_new_0.8_...
# 117         117  data/Only_training_hipotesis\0.8\TEST_new_0.8_...
# 118         118  data/Only_training_hipotesis\0.8\TEST_new_0.8_...
# 119         119  data/Only_training_hipotesis\0.8\TEST_new_0.8_...
# 120         120    data/Only_training_hipotesis\1\TEST_new_1_0.csv
#
#                                              1  grupo     error  accuracy
# 0    [0.42894517253426945, 0.8176470588235294]    5.0  0.428945  0.817647
# 1     [0.4750452953226426, 0.8117647058823529]    5.0  0.475045  0.811765
# 2     [0.4165754416409661, 0.8514705882352941]    5.0  0.416575  0.851471
# 3     [0.4415535737486447, 0.8264705882352941]    5.0  0.441554  0.826471
# 4     [0.4969964521772721, 0.8205882352941176]    5.0  0.496996  0.820588
# ..                                         ...    ...       ...       ...
# 116  [0.46185993282867066, 0.8291475710029672]   80.0  0.461860  0.829148
# 117  [0.45558229036881875, 0.8295142071056978]   80.0  0.455582  0.829514
# 118  [0.45798323377352257, 0.8309807516368128]   80.0  0.457983  0.830981
# 119   [0.4669914347113654, 0.8253895508270543]   80.0  0.466991  0.825390
# 120  [0.46506612251748575, 0.8271007479015098]  100.0  0.465066  0.827101
#
# [121 rows x 6 columns]

# %%
resultados.boxplot(column=['error', 'accuracy'],by='grupo',layout=(2, 1), fontsize=15,figsize=(20,10))
#resultados.boxplot(by='grupo')
# Out:
# array([<AxesSubplot:title={'center':'error'}, xlabel='grupo'>,
#        <AxesSubplot:title={'center':'accuracy'}, xlabel='grupo'>],
#       dtype=object)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
resultados.plot(column=['error', 'accuracy'],by='grupo',layout=(2, 1), fontsize=15,figsize=(20,10),subplots=True, 
    sharey=False,kind='box')
plt.axhline(y=0.85073, xmin=1, xmax=100)
plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# # Del corpus base vamos a quitar los del test y solo comparar con los de paráfraseo

# %%
a=glob.glob('data/Only_training_hipotesis_salida/*.pickle')
a[0]
# Out:
# 'data/Only_training_hipotesis_salida\\pTEST_new_0.05_0.csv.pickle'

# %%
def mayorEtiqueta(a,b,c):
    if a > b and a > c:
        return 'entailment'
    elif c > a and c > b:
        return 'contradiction'
    else:
        return 'neutral'

# %%
f=pd.read_pickle(a[0])
f
# Out:
#      Main index                                               Text  \
# 0             0  [NULL{null,ADJ}, two{two,NUM}, women{woman,NOU...
# 1             1  [NULL{null,PROPN}, a{a,DET}, black{black,ADJ},...
# 2             2  [NULL{null,ADJ}, two{two,NUM}, ladies{lady,NOU...
# 3             3  [NULL{null,PROPN}, a{a,DET}, person{person,NOU...
# 4             4  [NULL{null,PROPN}, a{a,DET}, young{young,ADJ},...
# ..          ...                                                ...
# 675         675  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, wi...
# 676         676  [NULL{null,ADJ}, girl{girl,NOUN}, wearing{wear...
# 677         677  [NULL{null,PROPN}, a{a,DET}, woman{woman,NOUN}...
# 678         678  [NULL{null,PROPN}, a{a,DET}, woman{woman,NOUN}...
# 679         679  [NULL{null,ADJ}, two{two,NUM}, men{man,NOUN}, ...
#
#                                              Hipotesis  \
# 0    [NULL{null,PROPN}, the{the,DET}, two{two,NUM},...
# 1    [NULL{null,ADJ}, there{there,ADV}, is{be,VERB}...
# 2    [NULL{null,ADJ}, two{two,NUM}, ladies{lady,NOU...
# 3    [NULL{null,PROPN}, a{a,DET}, individual{indivi...
# 4    [NULL{null,PROPN}, the{the,DET}, kids{kid,NOUN...
# ..                                                 ...
# 675  [NULL{null,PROPN}, he{-PRON-,PRON}, has{have,V...
# 676  [NULL{null,ADJ}, one{one,NUM}, plays{play,VERB...
# 677  [NULL{null,PROPN}, the{the,DET}, ma{ma,NOUN}, ...
# 678  [NULL{null,ADJ}, one{one,NUM}, reward{reward,N...
# 679  [NULL{null,PROPN}, a{a,DET}, crew{crew,NOUN}, ...
#
#                                                 R_Text  \
# 0    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 1    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 3    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 4    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# ..                                                 ...
# 675  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 676  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 677  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 678  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 679  [[0.016082555, 0.077160776, -0.013421837, 0.00...
#
#                                                  R_Hip  \
# 0    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 1    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 3    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 4    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# ..                                                 ...
# 675  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 676  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 677  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 678  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 679  [[0.016082555, 0.077160776, -0.013421837, 0.00...
#
#                                                M_Align  \
# 0    [[0.085589595, 0.004343943, 0.08687423, 0.2110...
# 1    [[0.085589595, 0.18873432, 0.016168319, 0.0140...
# 2    [[0.085589595, 0.08687423, 0.17911102, 0.09273...
# 3    [[0.085589595, 0.014024382, 0.10867564, 0.0724...
# 4    [[0.085589595, 0.004343943, 0.17104001, 0.0249...
# ..                                                 ...
# 675  [[0.085589595, 0.17840508, 0.023192137, 0.4689...
# 676  [[0.085589595, 0.103053674, 0.23011616, 0.1234...
# 677  [[0.085589595, 0.004343943, 0.11288659, 0.0161...
# 678  [[0.085589595, 0.103053674, 0.08744241, 0.0140...
# 679  [[0.085589595, 0.014024382, 0.15949261, 0.0161...
#
#                                    Prediction       Gold_label  Paraphrase  \
# 0       [0.006305703, 0.06551562, 0.92817867]  [0.0, 0.0, 1.0]           0
# 1    [0.99017394, 0.009517933, 0.00030803506]  [1.0, 0.0, 0.0]           0
# 2        [0.008069085, 0.9096557, 0.08227522]  [0.0, 1.0, 0.0]           0
# 3     [0.96718806, 0.028018078, 0.0047938903]  [1.0, 0.0, 0.0]           0
# 4        [0.014555042, 0.7734741, 0.21197085]  [0.0, 0.0, 1.0]           0
# ..                                        ...              ...         ...
# 675     [0.013301309, 0.011364532, 0.9753341]  [0.0, 0.0, 1.0]           1
# 676   [0.030716334, 0.96501446, 0.0042692097]  [0.0, 1.0, 0.0]           1
# 677       [0.4472339, 0.45994857, 0.09281755]  [0.0, 1.0, 0.0]           1
# 678      [0.004797376, 0.39436302, 0.6008396]  [0.0, 1.0, 0.0]           1
# 679     [0.84639627, 0.14704515, 0.006558569]  [1.0, 0.0, 0.0]           1
#
#       Idx
# 0    5974
# 1    9031
# 2    6904
# 3    7300
# 4    7779
# ..    ...
# 675  9610
# 676  9708
# 677  9726
# 678  9764
# 679  9793
#
# [680 rows x 10 columns]

# %% [markdown]
# # Procesar todos los archivos para obtener las etiquetas originales y las predicciones

# %%
# Procesar los archivos obtenidos para procesarlos y tener un nuevo archivo de las etiquetas originales vs etiquetas de predicción
for e in a:
    df_prediction=pd.read_pickle(e)
    temp=df_prediction.copy()
    df_prediction.assign(predicted_label="")
    df_prediction.assign(gold_label="")
    for index,strings in temp.iterrows():
        p_e=mayorEtiqueta(strings['Prediction'][0],strings['Prediction'][1],strings['Prediction'][2])
        g_e=mayorEtiqueta(strings['Gold_label'][0],strings['Gold_label'][1],strings['Gold_label'][2])
        df_prediction.at[index,'predicted_label']=p_e
        df_prediction.at[index,'gold_label']=g_e
    df_prediction.to_pickle(e)

# %%
a[0]
# Out:
# 'data/Only_training_hipotesis_salida\\pTEST_new_0.05_0.csv.pickle'

# %% [markdown]
# # Ya se tiene para todos los muestreos las etiquetas originales vs las predichas

# %%
new_data = {'Docs' : [], 'Total' : [], 'Total Entailment' : [], 'Total Entailment (E)' : [],
             'Total Entailment (N)' : [], 'Total Entailment (C)' : [], 'Total Neutral' : [],
             'Total Neutral (N)' : [], 'Total Neutral (E)' : [], 'Total Neutral (C)' : [],
             'Total Contradiction' : [],'Total Contradiction (C)' : [],'Total Contradiction (E)' : [],
             'Total Contradiction (N)' : [], 'grupo': [], 'parafraseo': []}
for e in a:
    df_predictionP=pd.read_pickle(e)
    for p in [0,1]:
        df_prediction=df_predictionP[df_predictionP["Paraphrase"]==p]
        c_entailment=df_prediction[(df_prediction['gold_label']=='entailment') & (df_prediction['predicted_label']=='entailment')].shape[0]
        cn_entailment=df_prediction[(df_prediction['gold_label']=='entailment') & (df_prediction['predicted_label']=='neutral')].shape[0]
        cc_entailment=df_prediction[(df_prediction['gold_label']=='entailment') & (df_prediction['predicted_label']=='contradiction')].shape[0]
        t_entailment=df_prediction[df_prediction['gold_label']=='entailment'].shape[0]
        c_neutral=df_prediction[(df_prediction['gold_label']=='neutral') & (df_prediction['predicted_label']=='neutral')].shape[0]
        ce_neutral=df_prediction[(df_prediction['gold_label']=='neutral') & (df_prediction['predicted_label']=='entailment')].shape[0]
        cc_neutral=df_prediction[(df_prediction['gold_label']=='neutral') & (df_prediction['predicted_label']=='contradiction')].shape[0]
        t_neutral=df_prediction[df_prediction['gold_label']=='neutral'].shape[0]
        c_contradiction=df_prediction[(df_prediction['gold_label']=='contradiction') & (df_prediction['predicted_label']=='contradiction')].shape[0]
        ce_contradiction=df_prediction[(df_prediction['gold_label']=='contradiction') & (df_prediction['predicted_label']=='entailment')].shape[0]
        cn_contradiction=df_prediction[(df_prediction['gold_label']=='contradiction') & (df_prediction['predicted_label']=='neutral')].shape[0]
        t_contradiction=df_prediction[df_prediction['gold_label']=='contradiction'].shape[0]
        new_data['Docs'].append(e)
        new_data['Total'].append(df_prediction.shape[0])
        new_data['Total Entailment'].append(t_entailment)
        new_data['Total Entailment (E)'].append(c_entailment)
        new_data['Total Entailment (N)'].append(cn_entailment)
        new_data['Total Entailment (C)'].append(cc_entailment)
        new_data['Total Neutral'].append(t_neutral)
        new_data['Total Neutral (E)'].append(ce_neutral)
        new_data['Total Neutral (N)'].append(c_neutral)
        new_data['Total Neutral (C)'].append(cc_neutral)
        new_data['Total Contradiction'].append(t_contradiction)
        new_data['Total Contradiction (E)'].append(ce_contradiction)
        new_data['Total Contradiction (N)'].append(cn_contradiction)
        new_data['Total Contradiction (C)'].append(c_contradiction)
        new_data['grupo'].append(float(e.split('_')[5])*100)
        new_data['parafraseo'].append(p)
new_data=pd.DataFrame(new_data)
new_data.to_csv("data/Only_training_hipotesis_salida/predictions/Fresultados.csv")

# %%
new_data = pd.read_csv("data/Only_training_hipotesis_salida/predictions/Fresultados.csv")
new_data
# Out:
#      Unnamed: 0                                               Docs  Total  \
# 0             0  data/Only_training_hipotesis_salida\pTEST_new_...    340
# 1             1  data/Only_training_hipotesis_salida\pTEST_new_...    340
# 2             2  data/Only_training_hipotesis_salida\pTEST_new_...    340
# 3             3  data/Only_training_hipotesis_salida\pTEST_new_...    340
# 4             4  data/Only_training_hipotesis_salida\pTEST_new_...    340
# ..          ...                                                ...    ...
# 237         237  data/Only_training_hipotesis_salida\pTEST_new_...   5455
# 238         238  data/Only_training_hipotesis_salida\pTEST_new_...   5455
# 239         239  data/Only_training_hipotesis_salida\pTEST_new_...   5455
# 240         240  data/Only_training_hipotesis_salida\pTEST_new_...   6819
# 241         241  data/Only_training_hipotesis_salida\pTEST_new_...   6819
#
#      Total Entailment  Total Entailment (E)  Total Entailment (N)  \
# 0                 101                    91                     8
# 1                 101                    86                    10
# 2                 104                    89                    12
# 3                 104                    87                    11
# 4                 108                   100                     5
# ..                ...                   ...                   ...
# 237              1679                  1383                   227
# 238              1721                  1495                   184
# 239              1721                  1402                   248
# 240              2120                  1859                   213
# 241              2120                  1734                   299
#
#      Total Entailment (C)  Total Neutral  Total Neutral (N)  \
# 0                       2            135                104
# 1                       5            135                103
# 2                       3            107                 89
# 3                       6            107                 81
# 4                       3            124                108
# ..                    ...            ...                ...
# 237                    69           1972               1545
# 238                    42           1969               1624
# 239                    71           1969               1539
# 240                    48           2435               2011
# 241                    87           2435               1906
#
#      Total Neutral (E)  Total Neutral (C)  Total Contradiction  \
# 0                   16                 15                  104
# 1                   15                 17                  104
# 2                   10                  8                  129
# 3                   13                 13                  129
# 4                    6                 10                  108
# ..                 ...                ...                  ...
# 237                209                218                 1804
# 238                185                160                 1765
# 239                206                224                 1765
# 240                238                186                 2264
# 241                262                267                 2264
#
#      Total Contradiction (C)  Total Contradiction (E)  \
# 0                         87                        0
# 1                         85                        3
# 2                        103                        6
# 3                        103                        6
# 4                         91                        6
# ..                       ...                      ...
# 237                     1488                       90
# 238                     1497                       66
# 239                     1448                       90
# 240                     1918                       88
# 241                     1852                      124
#
#      Total Contradiction (N)  grupo  parafraseo
# 0                         17    5.0           0
# 1                         16    5.0           1
# 2                         20    5.0           0
# 3                         20    5.0           1
# 4                         11    5.0           0
# ..                       ...    ...         ...
# 237                      226   80.0           1
# 238                      202   80.0           0
# 239                      227   80.0           1
# 240                      258  100.0           0
# 241                      288  100.0           1
#
# [242 rows x 17 columns]

# %%
new_data.boxplot(column=['Total', 'Total Entailment','Total Neutral','Total Contradiction'],by=['grupo', 'parafraseo'],fontsize=13,figsize=(20,10),rot=90)
#new_data.boxplot()
# Out:
# array([[<AxesSubplot:title={'center':'Total'}, xlabel='[grupo, parafraseo]'>,
#         <AxesSubplot:title={'center':'Total Entailment'}, xlabel='[grupo, parafraseo]'>],
#        [<AxesSubplot:title={'center':'Total Neutral'}, xlabel='[grupo, parafraseo]'>,
#         <AxesSubplot:title={'center':'Total Contradiction'}, xlabel='[grupo, parafraseo]'>]],
#       dtype=object)

# %%
new_data.boxplot(column=['Total Entailment','Total Entailment (E)','Total Entailment (N)','Total Entailment (C)',],by='grupo',fontsize=13,figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Total Entailment'}, xlabel='grupo'>,
#         <AxesSubplot:title={'center':'Total Entailment (E)'}, xlabel='grupo'>],
#        [<AxesSubplot:title={'center':'Total Entailment (N)'}, xlabel='grupo'>,
#         <AxesSubplot:title={'center':'Total Entailment (C)'}, xlabel='grupo'>]],
#       dtype=object)

# %%
new_data.boxplot(column=['Total Neutral','Total Neutral (N)','Total Neutral (E)','Total Neutral (C)',],by='grupo',fontsize=13,figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Total Neutral'}, xlabel='grupo'>,
#         <AxesSubplot:title={'center':'Total Neutral (N)'}, xlabel='grupo'>],
#        [<AxesSubplot:title={'center':'Total Neutral (E)'}, xlabel='grupo'>,
#         <AxesSubplot:title={'center':'Total Neutral (C)'}, xlabel='grupo'>]],
#       dtype=object)

# %%
new_data.boxplot(column=['Total Contradiction'],by='grupo',fontsize=13,figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'Total Contradiction'}, xlabel='grupo'>

# %%
new_data.boxplot(column=['Total Contradiction','Total Contradiction (C)','Total Contradiction (E)','Total Contradiction (N)',],by='grupo',fontsize=13,figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Total Contradiction'}, xlabel='grupo'>,
#         <AxesSubplot:title={'center':'Total Contradiction (C)'}, xlabel='grupo'>],
#        [<AxesSubplot:title={'center':'Total Contradiction (E)'}, xlabel='grupo'>,
#         <AxesSubplot:title={'center':'Total Contradiction (N)'}, xlabel='grupo'>]],
#       dtype=object)
