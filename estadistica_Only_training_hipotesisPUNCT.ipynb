# %%
import pandas as pd
import glob

# %% [markdown]
# # Procesamiento de datos

# %%
resultados=pd.read_csv("data/Only_training_hipotesisPUNCT_salida/resultados.csv")
resultados
# Out:
#      Unnamed: 0                                                  0  \
# 0             0  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# 1             1  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# 2             2  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# 3             3  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# 4             4  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# ..          ...                                                ...
# 116         116  data/Only_training_hipotesisPUNCT/0.2/TEST_new...
# 117         117  data/Only_training_hipotesisPUNCT/0.2/TEST_new...
# 118         118  data/Only_training_hipotesisPUNCT/0.2/TEST_new...
# 119         119  data/Only_training_hipotesisPUNCT/0.2/TEST_new...
# 120         120  data/Only_training_hipotesisPUNCT/1/TEST_new_1...
#
#                                              1
# 0       [0.55942628961325, 0.7951070336391437]
# 1    [0.49784626086621536, 0.8159257659739237]
# 2        [0.57042751555243, 0.790061065537675]
# 3     [0.5597638834505191, 0.7864753207348564]
# 4     [0.5135071467957961, 0.8169681309216192]
# ..                                         ...
# 116   [0.5309367517620535, 0.7996410507909975]
# 117   [0.5685556396373903, 0.7856675392670157]
# 118   [0.5336971086684315, 0.8043229080308415]
# 119   [0.5576436687039014, 0.7882199380482988]
# 120    [0.5437621115708374, 0.794930126758454]
#
# [121 rows x 3 columns]

# %%
resultados=resultados.assign(grupo=0.0)
resultados=resultados.assign(error=0.0)
resultados=resultados.assign(accuracy=0.0)

# %%
resultados
# Out:
#      Unnamed: 0                                                  0  \
# 0             0  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# 1             1  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# 2             2  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# 3             3  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# 4             4  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# ..          ...                                                ...
# 116         116  data/Only_training_hipotesisPUNCT/0.2/TEST_new...
# 117         117  data/Only_training_hipotesisPUNCT/0.2/TEST_new...
# 118         118  data/Only_training_hipotesisPUNCT/0.2/TEST_new...
# 119         119  data/Only_training_hipotesisPUNCT/0.2/TEST_new...
# 120         120  data/Only_training_hipotesisPUNCT/1/TEST_new_1...
#
#                                              1  grupo  error  accuracy
# 0       [0.55942628961325, 0.7951070336391437]    0.0    0.0       0.0
# 1    [0.49784626086621536, 0.8159257659739237]    0.0    0.0       0.0
# 2        [0.57042751555243, 0.790061065537675]    0.0    0.0       0.0
# 3     [0.5597638834505191, 0.7864753207348564]    0.0    0.0       0.0
# 4     [0.5135071467957961, 0.8169681309216192]    0.0    0.0       0.0
# ..                                         ...    ...    ...       ...
# 116   [0.5309367517620535, 0.7996410507909975]    0.0    0.0       0.0
# 117   [0.5685556396373903, 0.7856675392670157]    0.0    0.0       0.0
# 118   [0.5336971086684315, 0.8043229080308415]    0.0    0.0       0.0
# 119   [0.5576436687039014, 0.7882199380482988]    0.0    0.0       0.0
# 120    [0.5437621115708374, 0.794930126758454]    0.0    0.0       0.0
#
# [121 rows x 6 columns]

# %%
temp=resultados.copy()
for index,strings in temp.iterrows():
    resultados.at[index,'grupo']=float(strings[1].split('_')[4])*100
    resultados.at[index,'error']=float(strings[2].split(',')[0][1:])
    resultados.at[index,'accuracy']=float(strings[2].split(',')[1][:-1])
resultados
# Out:
#      Unnamed: 0                                                  0  \
# 0             0  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# 1             1  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# 2             2  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# 3             3  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# 4             4  data/Only_training_hipotesisPUNCT/0.15/TEST_ne...
# ..          ...                                                ...
# 116         116  data/Only_training_hipotesisPUNCT/0.2/TEST_new...
# 117         117  data/Only_training_hipotesisPUNCT/0.2/TEST_new...
# 118         118  data/Only_training_hipotesisPUNCT/0.2/TEST_new...
# 119         119  data/Only_training_hipotesisPUNCT/0.2/TEST_new...
# 120         120  data/Only_training_hipotesisPUNCT/1/TEST_new_1...
#
#                                              1  grupo     error  accuracy
# 0       [0.55942628961325, 0.7951070336391437]   15.0  0.559426  0.795107
# 1    [0.49784626086621536, 0.8159257659739237]   15.0  0.497846  0.815926
# 2        [0.57042751555243, 0.790061065537675]   15.0  0.570428  0.790061
# 3     [0.5597638834505191, 0.7864753207348564]   15.0  0.559764  0.786475
# 4     [0.5135071467957961, 0.8169681309216192]   15.0  0.513507  0.816968
# ..                                         ...    ...       ...       ...
# 116   [0.5309367517620535, 0.7996410507909975]   20.0  0.530937  0.799641
# 117   [0.5685556396373903, 0.7856675392670157]   20.0  0.568556  0.785668
# 118   [0.5336971086684315, 0.8043229080308415]   20.0  0.533697  0.804323
# 119   [0.5576436687039014, 0.7882199380482988]   20.0  0.557644  0.788220
# 120    [0.5437621115708374, 0.794930126758454]  100.0  0.543762  0.794930
#
# [121 rows x 6 columns]

# %%
resultados.boxplot(column=['error', 'accuracy'],by='grupo',layout=(2, 1), fontsize=15,figsize=(20,10))
#resultados.boxplot(by='grupo')
# Out:
# array([<AxesSubplot:title={'center':'error'}, xlabel='grupo'>,
#        <AxesSubplot:title={'center':'accuracy'}, xlabel='grupo'>],
#       dtype=object)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
resultados.plot(column=['error', 'accuracy'],by='grupo',layout=(2, 1), fontsize=15,figsize=(20,10),subplots=True, 
    sharey=False,kind='box')
plt.axhline(y=0.85073, xmin=1, xmax=100)
plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# # Del corpus base vamos a quitar los del test y solo comparar con los de paráfraseo

# %%
a=glob.glob('data/Only_training_hipotesis_salida/*.pickle')
a[0]
# Out:
# 'data/Only_training_hipotesis_salida/pTEST_new_0.2_9.csv.pickle'

# %%
def mayorEtiqueta(a,b,c):
    if a > b and a > c:
        return 'entailment'
    elif c > a and c > b:
        return 'contradiction'
    else:
        return 'neutral'

# %%
f=pd.read_pickle(a[0])
f
# Out:
#       Main index                                               Text  \
# 0              0  [NULL{null,PROPN}, a{a,DET}, little{little,ADJ...
# 1              1  [NULL{null,ADJ}, people{people,NOUN}, landscap...
# 2              2  [NULL{null,ADJ}, man{man,NOUN}, with{with,ADP}...
# 3              3  [NULL{null,ADJ}, two{two,NUM}, females{female,...
# 4              4  [NULL{null,ADJ}, man{man,NOUN}, with{with,ADP}...
# ...          ...                                                ...
# 2721        2721  [NULL{null,PROPN}, a{a,DET}, woman{woman,NOUN}...
# 2722        2722  [NULL{null,ADJ}, two{two,NUM}, men{man,NOUN}, ...
# 2723        2723  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, we...
# 2724        2724  [NULL{null,ADJ}, two{two,NUM}, women{woman,NOU...
# 2725        2725  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, in...
#
#                                               Hipotesis  \
# 0     [NULL{null,PROPN}, the{the,DET}, girl{girl,NOU...
# 1     [NULL{null,ADJ}, people{people,NOUN}, are{be,V...
# 2     [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, wi...
# 3     [NULL{null,ADJ}, people{people,NOUN}, are{be,V...
# 4     [NULL{null,PROPN}, the{the,DET}, man{man,NOUN}...
# ...                                                 ...
# 2721  [NULL{null,PROPN}, a{a,DET}, few{few,ADJ}, coo...
# 2722  [NULL{null,INTJ}, no{no,DET}, one{one,NOUN}, i...
# 2723  [NULL{null,ADJ}, one{one,NOUN}, with{with,ADP}...
# 2724  [NULL{null,ADJ}, two{two,NUM}, girls{girl,NOUN...
# 2725  [NULL{null,ADJ}, two{two,NUM}, teaching{teach,...
#
#                                                  R_Text  \
# 0     [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 1     [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2     [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 3     [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 4     [[0.016082555, 0.077160776, -0.013421837, 0.00...
# ...                                                 ...
# 2721  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2722  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2723  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2724  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2725  [[0.016082555, 0.077160776, -0.013421837, 0.00...
#
#                                                   R_Hip  \
# 0     [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 1     [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2     [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 3     [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 4     [[0.016082555, 0.077160776, -0.013421837, 0.00...
# ...                                                 ...
# 2721  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2722  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2723  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2724  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2725  [[0.016082555, 0.077160776, -0.013421837, 0.00...
#
#                                                 M_Align  \
# 0     [[0.085589595, 0.004343943, 0.17582855, 0.0051...
# 1     [[0.085589595, 0.16620766, 0.011193112, 0.1601...
# 2     [[0.085589595, 0.014024382, 0.1707767, 0.00511...
# 3     [[0.085589595, 0.16620766, 0.011193112, 0.0352...
# 4     [[0.085589595, 0.004343943, 0.1707767, 0.02319...
# ...                                                 ...
# 2721  [[0.085589595, 0.014024382, 0.13514067, 0.1475...
# 2722  [[0.085589595, 0.5133731, 0.103053674, 0.01616...
# 2723  [[0.085589595, 0.103053674, 0.0051167835, 0.23...
# 2724  [[0.085589595, 0.08687423, 0.21120092, 0.01119...
# 2725  [[0.085589595, 0.08687423, 0.15585363, 0.24149...
#
#                                    Prediction       Gold_label  Paraphrase  \
# 0       [0.73986155, 0.21198581, 0.048152573]  [1.0, 0.0, 0.0]           0
# 1      [0.089671984, 0.9036437, 0.0066843526]  [1.0, 0.0, 0.0]           0
# 2          [0.5843813, 0.3592317, 0.05638696]  [0.0, 1.0, 0.0]           0
# 3       [0.75636595, 0.20552766, 0.038106415]  [1.0, 0.0, 0.0]           0
# 4        [0.012069525, 0.010695389, 0.977235]  [0.0, 0.0, 1.0]           0
# ...                                       ...              ...         ...
# 2721      [0.0367556, 0.9514451, 0.011799323]  [0.0, 1.0, 0.0]           1
# 2722  [0.0011920021, 0.0025028302, 0.9963052]  [0.0, 0.0, 1.0]           1
# 2723     [0.8575601, 0.049335785, 0.09310413]  [1.0, 0.0, 0.0]           1
# 2724     [0.7249473, 0.22226317, 0.052789494]  [1.0, 0.0, 0.0]           1
# 2725     [0.23783317, 0.65513325, 0.10703362]  [0.0, 1.0, 0.0]           1
#
#        Idx predicted_label     gold_label  \
# 0     6801      entailment     entailment
# 1     9663         neutral     entailment
# 2     1216      entailment        neutral
# 3     5572      entailment     entailment
# 4     1541   contradiction  contradiction
# ...    ...             ...            ...
# 2721  9789         neutral        neutral
# 2722  9792   contradiction  contradiction
# 2723  9808      entailment     entailment
# 2724  9814      entailment     entailment
# 2725  9817         neutral        neutral
#
#                                               ma_umbral  \
# 0                                                   ...
# 1                 NOUN                   VERB       ...
# 2                                                   ...
# 3                                                   ...
# 4                                                   ...
# ...                                                 ...
# 2721                                                ...
# 2722             NOUN VERB ADP ADV ADJ
# NOUN  ,1.2367...
# 2723                                                ...
# 2724                        NOUN                   V...
# 2725                                                ...
#
#                 target_prediction
# 0           entailment_entailment
# 1              entailment_neutral
# 2              neutral_entailment
# 3           entailment_entailment
# 4     contradiction_contradiction
# ...                           ...
# 2721              neutral_neutral
# 2722  contradiction_contradiction
# 2723        entailment_entailment
# 2724        entailment_entailment
# 2725              neutral_neutral
#
# [2726 rows x 14 columns]

# %% [markdown]
# # Procesar todos los archivos para obtener las etiquetas originales y las predicciones

# %%
# Procesar los archivos obtenidos para procesarlos y tener un nuevo archivo de las etiquetas originales vs etiquetas de predicción
for e in a:
    df_prediction=pd.read_pickle(e)
    temp=df_prediction.copy()
    df_prediction.assign(predicted_label="")
    df_prediction.assign(gold_label="")
    for index,strings in temp.iterrows():
        p_e=mayorEtiqueta(strings['Prediction'][0],strings['Prediction'][1],strings['Prediction'][2])
        g_e=mayorEtiqueta(strings['Gold_label'][0],strings['Gold_label'][1],strings['Gold_label'][2])
        df_prediction.at[index,'predicted_label']=p_e
        df_prediction.at[index,'gold_label']=g_e
    df_prediction.to_pickle(e)

# %%
a[0]
# Out:
# 'data/Only_training_hipotesis_salida/pTEST_new_0.2_9.csv.pickle'

# %% [markdown]
# # Ya se tiene para todos los muestreos las etiquetas originales vs las predichas

# %%
new_data = {'Docs' : [], 'Total' : [], 'Total Entailment' : [], 'Total Entailment (E)' : [],
             'Total Entailment (N)' : [], 'Total Entailment (C)' : [], 'Total Neutral' : [],
             'Total Neutral (N)' : [], 'Total Neutral (E)' : [], 'Total Neutral (C)' : [],
             'Total Contradiction' : [],'Total Contradiction (C)' : [],'Total Contradiction (E)' : [],
             'Total Contradiction (N)' : [], 'grupo': [], 'parafraseo': []}
for e in a:
    df_predictionP=pd.read_pickle(e)
    for p in [0,1]:
        df_prediction=df_predictionP[df_predictionP["Paraphrase"]==p]
        c_entailment=df_prediction[(df_prediction['gold_label']=='entailment') & (df_prediction['predicted_label']=='entailment')].shape[0]
        cn_entailment=df_prediction[(df_prediction['gold_label']=='entailment') & (df_prediction['predicted_label']=='neutral')].shape[0]
        cc_entailment=df_prediction[(df_prediction['gold_label']=='entailment') & (df_prediction['predicted_label']=='contradiction')].shape[0]
        t_entailment=df_prediction[df_prediction['gold_label']=='entailment'].shape[0]
        c_neutral=df_prediction[(df_prediction['gold_label']=='neutral') & (df_prediction['predicted_label']=='neutral')].shape[0]
        ce_neutral=df_prediction[(df_prediction['gold_label']=='neutral') & (df_prediction['predicted_label']=='entailment')].shape[0]
        cc_neutral=df_prediction[(df_prediction['gold_label']=='neutral') & (df_prediction['predicted_label']=='contradiction')].shape[0]
        t_neutral=df_prediction[df_prediction['gold_label']=='neutral'].shape[0]
        c_contradiction=df_prediction[(df_prediction['gold_label']=='contradiction') & (df_prediction['predicted_label']=='contradiction')].shape[0]
        ce_contradiction=df_prediction[(df_prediction['gold_label']=='contradiction') & (df_prediction['predicted_label']=='entailment')].shape[0]
        cn_contradiction=df_prediction[(df_prediction['gold_label']=='contradiction') & (df_prediction['predicted_label']=='neutral')].shape[0]
        t_contradiction=df_prediction[df_prediction['gold_label']=='contradiction'].shape[0]
        new_data['Docs'].append(e)
        new_data['Total'].append(df_prediction.shape[0])
        new_data['Total Entailment'].append(t_entailment)
        new_data['Total Entailment (E)'].append(c_entailment)
        new_data['Total Entailment (N)'].append(cn_entailment)
        new_data['Total Entailment (C)'].append(cc_entailment)
        new_data['Total Neutral'].append(t_neutral)
        new_data['Total Neutral (E)'].append(ce_neutral)
        new_data['Total Neutral (N)'].append(c_neutral)
        new_data['Total Neutral (C)'].append(cc_neutral)
        new_data['Total Contradiction'].append(t_contradiction)
        new_data['Total Contradiction (E)'].append(ce_contradiction)
        new_data['Total Contradiction (N)'].append(cn_contradiction)
        new_data['Total Contradiction (C)'].append(c_contradiction)
        new_data['grupo'].append(float(e.split('_')[5])*100)
        new_data['parafraseo'].append(p)
new_data=pd.DataFrame(new_data)
new_data.to_csv("data/Only_training_hipotesisPUNCT_salida/predictions/Fresultados.csv")

# %%
new_data = pd.read_csv("data/Only_training_hipotesisPUNCT_salida/predictions/Fresultados.csv")
new_data
# Out:
#      Unnamed: 0                                               Docs  Total  \
# 0             0  data/Only_training_hipotesis_salida/pTEST_new_...   1363
# 1             1  data/Only_training_hipotesis_salida/pTEST_new_...   1363
# 2             2  data/Only_training_hipotesis_salida/pTEST_new_...   3409
# 3             3  data/Only_training_hipotesis_salida/pTEST_new_...   3409
# 4             4  data/Only_training_hipotesis_salida/pTEST_new_...   1022
# ..          ...                                                ...    ...
# 237         237  data/Only_training_hipotesis_salida/pTEST_new_...    681
# 238         238  data/Only_training_hipotesis_salida/pTEST_new_...    681
# 239         239  data/Only_training_hipotesis_salida/pTEST_new_...    681
# 240         240  data/Only_training_hipotesis_salida/pTEST_new_...   3409
# 241         241  data/Only_training_hipotesis_salida/pTEST_new_...   3409
#
#      Total Entailment  Total Entailment (E)  Total Entailment (N)  \
# 0                 430                   375                    45
# 1                 430                   350                    65
# 2                1067                   937                   102
# 3                1067                   865                   162
# 4                 308                   266                    35
# ..                ...                   ...                   ...
# 237               226                   184                    28
# 238               197                   167                    23
# 239               197                   160                    27
# 240              1077                   937                   117
# 241              1077                   888                   149
#
#      Total Entailment (C)  Total Neutral  Total Neutral (N)  \
# 0                      10            497                408
# 1                      15            497                379
# 2                      28           1218               1015
# 3                      40           1218                962
# 4                       7            378                308
# ..                    ...            ...                ...
# 237                    14            229                182
# 238                     7            250                195
# 239                    10            250                183
# 240                    23           1183                973
# 241                    40           1183                923
#
#      Total Neutral (E)  Total Neutral (C)  Total Contradiction  \
# 0                   46                 43                  436
# 1                   56                 62                  436
# 2                  109                 94                 1124
# 3                  132                124                 1124
# 4                   35                 35                  336
# ..                 ...                ...                  ...
# 237                 23                 24                  226
# 238                 29                 26                  234
# 239                 32                 35                  234
# 240                123                 87                 1149
# 241                133                127                 1149
#
#      Total Contradiction (C)  Total Contradiction (E)  \
# 0                        373                       12
# 1                        366                       21
# 2                        950                       39
# 3                        908                       60
# 4                        293                        7
# ..                       ...                      ...
# 237                      184                       11
# 238                      193                       13
# 239                      188                       13
# 240                      974                       48
# 241                      934                       66
#
#      Total Contradiction (N)  grupo  parafraseo
# 0                         51   20.0           0
# 1                         49   20.0           1
# 2                        135   50.0           0
# 3                        156   50.0           1
# 4                         36   15.0           0
# ..                       ...    ...         ...
# 237                       31   10.0           1
# 238                       28   10.0           0
# 239                       33   10.0           1
# 240                      127   50.0           0
# 241                      149   50.0           1
#
# [242 rows x 17 columns]

# %%
new_data.boxplot(column=['Total', 'Total Entailment','Total Neutral','Total Contradiction'],by=['grupo', 'parafraseo'],fontsize=13,figsize=(20,10),rot=90)
#new_data.boxplot()
# Out:
# array([[<AxesSubplot:title={'center':'Total'}, xlabel='[grupo, parafraseo]'>,
#         <AxesSubplot:title={'center':'Total Entailment'}, xlabel='[grupo, parafraseo]'>],
#        [<AxesSubplot:title={'center':'Total Neutral'}, xlabel='[grupo, parafraseo]'>,
#         <AxesSubplot:title={'center':'Total Contradiction'}, xlabel='[grupo, parafraseo]'>]],
#       dtype=object)

# %%
new_data.boxplot(column=['Total Entailment','Total Entailment (E)','Total Entailment (N)','Total Entailment (C)',],by='grupo',fontsize=13,figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Total Entailment'}, xlabel='grupo'>,
#         <AxesSubplot:title={'center':'Total Entailment (E)'}, xlabel='grupo'>],
#        [<AxesSubplot:title={'center':'Total Entailment (N)'}, xlabel='grupo'>,
#         <AxesSubplot:title={'center':'Total Entailment (C)'}, xlabel='grupo'>]],
#       dtype=object)

# %%
new_data.boxplot(column=['Total Neutral','Total Neutral (N)','Total Neutral (E)','Total Neutral (C)',],by='grupo',fontsize=13,figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Total Neutral'}, xlabel='grupo'>,
#         <AxesSubplot:title={'center':'Total Neutral (N)'}, xlabel='grupo'>],
#        [<AxesSubplot:title={'center':'Total Neutral (E)'}, xlabel='grupo'>,
#         <AxesSubplot:title={'center':'Total Neutral (C)'}, xlabel='grupo'>]],
#       dtype=object)

# %%
new_data.boxplot(column=['Total Contradiction'],by='grupo',fontsize=13,figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'Total Contradiction'}, xlabel='grupo'>

# %%
new_data.boxplot(column=['Total Contradiction','Total Contradiction (C)','Total Contradiction (E)','Total Contradiction (N)',],by='grupo',fontsize=13,figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Total Contradiction'}, xlabel='grupo'>,
#         <AxesSubplot:title={'center':'Total Contradiction (C)'}, xlabel='grupo'>],
#        [<AxesSubplot:title={'center':'Total Contradiction (E)'}, xlabel='grupo'>,
#         <AxesSubplot:title={'center':'Total Contradiction (N)'}, xlabel='grupo'>]],
#       dtype=object)
