# %%
import pandas as pd
import numpy as np
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
carpeta="data/Only_training_hipotesis_salida/"

# %%
dfn=pd.read_pickle(carpeta+"entropia/resultados_entropiaZSCORE_Transponse.pickle")

# %%
dfn
# Out:
#                                                    Docs  grupo      muestreo  \
# 0     data/Only_training_hipotesis_salida\pTEST_new_...    5.0  0.csv.pickle
# 1     data/Only_training_hipotesis_salida\pTEST_new_...    5.0  0.csv.pickle
# 2     data/Only_training_hipotesis_salida\pTEST_new_...    5.0  0.csv.pickle
# 3     data/Only_training_hipotesis_salida\pTEST_new_...    5.0  0.csv.pickle
# 4     data/Only_training_hipotesis_salida\pTEST_new_...    5.0  0.csv.pickle
# ...                                                 ...    ...           ...
# 2173  data/Only_training_hipotesis_salida\pTEST_new_...  100.0  0.csv.pickle
# 2174  data/Only_training_hipotesis_salida\pTEST_new_...  100.0  0.csv.pickle
# 2175  data/Only_training_hipotesis_salida\pTEST_new_...  100.0  0.csv.pickle
# 2176  data/Only_training_hipotesis_salida\pTEST_new_...  100.0  0.csv.pickle
# 2177  data/Only_training_hipotesis_salida\pTEST_new_...  100.0  0.csv.pickle
#
#       Total  Subtotal                          E_P  \
# 0       101        91        entailment_entailment
# 1       101         7           entailment_neutral
# 2       101         3     entailment_contradiction
# 3       135        17           neutral_entailment
# 4       135       103              neutral_neutral
# ...     ...       ...                          ...
# 2173   2435      1904              neutral_neutral
# 2174   2435       265        neutral_contradiction
# 2175   2264       122     contradiction_entailment
# 2176   2264       287        contradiction_neutral
# 2177   2264      1855  contradiction_contradiction
#
#                                                entropia  Paraphrase
# 0     [5.781, 6.533, 6.585, 7.789, 6.226, 5.129, 6.5...           0
# 1     [6.962, 6.596, 6.607, 5.596, 4.644, 6.472, 6.819]           0
# 2                                 [6.465, 7.334, 6.982]           0
# 3     [5.657, 5.977, 5.586, 6.609, 5.295, 6.187, 6.5...           0
# 4     [7.186, 7.002, 6.28, 6.226, 6.913, 5.557, 5.52...           0
# ...                                                 ...         ...
# 2173  [5.468, 6.797, 5.773, 5.807, 6.766, 7.233, 5.5...           1
# 2174  [6.533, 6.862, 6.975, 5.107, 6.701, 5.948, 6.7...           1
# 2175  [5.74, 6.059, 5.492, 6.824, 6.808, 4.644, 6.24...           1
# 2176  [5.576, 6.129, 5.755, 5.491, 3.17, 7.339, 6.64...           1
# 2177  [6.755, 5.642, 6.459, 5.247, 5.863, 5.977, 6.8...           1
#
# [2178 rows x 8 columns]

# %%
dfn=dfn.assign(relacion=dfn["Subtotal"]/dfn["Total"])
dfn
# Out:
#                                                    Docs  grupo      muestreo  \
# 0     data/Only_training_hipotesis_salida\pTEST_new_...    5.0  0.csv.pickle
# 1     data/Only_training_hipotesis_salida\pTEST_new_...    5.0  0.csv.pickle
# 2     data/Only_training_hipotesis_salida\pTEST_new_...    5.0  0.csv.pickle
# 3     data/Only_training_hipotesis_salida\pTEST_new_...    5.0  0.csv.pickle
# 4     data/Only_training_hipotesis_salida\pTEST_new_...    5.0  0.csv.pickle
# ...                                                 ...    ...           ...
# 2173  data/Only_training_hipotesis_salida\pTEST_new_...  100.0  0.csv.pickle
# 2174  data/Only_training_hipotesis_salida\pTEST_new_...  100.0  0.csv.pickle
# 2175  data/Only_training_hipotesis_salida\pTEST_new_...  100.0  0.csv.pickle
# 2176  data/Only_training_hipotesis_salida\pTEST_new_...  100.0  0.csv.pickle
# 2177  data/Only_training_hipotesis_salida\pTEST_new_...  100.0  0.csv.pickle
#
#       Total  Subtotal                          E_P  \
# 0       101        91        entailment_entailment
# 1       101         7           entailment_neutral
# 2       101         3     entailment_contradiction
# 3       135        17           neutral_entailment
# 4       135       103              neutral_neutral
# ...     ...       ...                          ...
# 2173   2435      1904              neutral_neutral
# 2174   2435       265        neutral_contradiction
# 2175   2264       122     contradiction_entailment
# 2176   2264       287        contradiction_neutral
# 2177   2264      1855  contradiction_contradiction
#
#                                                entropia  Paraphrase  relacion
# 0     [5.781, 6.533, 6.585, 7.789, 6.226, 5.129, 6.5...           0  0.900990
# 1     [6.962, 6.596, 6.607, 5.596, 4.644, 6.472, 6.819]           0  0.069307
# 2                                 [6.465, 7.334, 6.982]           0  0.029703
# 3     [5.657, 5.977, 5.586, 6.609, 5.295, 6.187, 6.5...           0  0.125926
# 4     [7.186, 7.002, 6.28, 6.226, 6.913, 5.557, 5.52...           0  0.762963
# ...                                                 ...         ...       ...
# 2173  [5.468, 6.797, 5.773, 5.807, 6.766, 7.233, 5.5...           1  0.781930
# 2174  [6.533, 6.862, 6.975, 5.107, 6.701, 5.948, 6.7...           1  0.108830
# 2175  [5.74, 6.059, 5.492, 6.824, 6.808, 4.644, 6.24...           1  0.053887
# 2176  [5.576, 6.129, 5.755, 5.491, 3.17, 7.339, 6.64...           1  0.126767
# 2177  [6.755, 5.642, 6.459, 5.247, 5.863, 5.977, 6.8...           1  0.819346
#
# [2178 rows x 9 columns]

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
dfn_5=dfn[dfn["grupo"]==5.0]
dfn_10=dfn[dfn["grupo"]==10.0]
dfn_15=dfn[dfn["grupo"]==15.0]
dfn_20=dfn[dfn["grupo"]==20.0]
dfn_50=dfn[dfn["grupo"]==50.0]
dfn_80=dfn[dfn["grupo"]==80.0]
dfn_100=dfn[dfn["grupo"]==100.0]

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn_5,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn_15,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn_50,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn_100,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
dfn0=dfn[dfn["Paraphrase"]==0]
dfn1=dfn[dfn["Paraphrase"]==1]

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn0,x="grupo",y="relacion", hue="E_P")
# Out:
# <AxesSubplot:xlabel='grupo', ylabel='relacion'>

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn1,x="grupo",y="relacion", hue="E_P")
# Out:
# <AxesSubplot:xlabel='grupo', ylabel='relacion'>

# %% [markdown]
# ## Los anteriores resultados muestran que en cada muestreo hay una gran diferencia de los aciertos vs los errores.
# ## Con la paráfrasis se obtiene un incremento en la predicción de contradiction, pero con este modelo se obtiene más errores entre los entailment_entailment y neutral_neutral
# ## En otras palabras, el texo paráfraseado mueve los valores de la predicción hacia la contradición de la inferencia. Así para todas las predicciones.
