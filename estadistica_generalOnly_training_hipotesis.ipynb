# %%
import pandas as pd
import numpy as np
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
carpeta="data/Only_training_hipotesis_salida/"

# %%
dfn=pd.read_pickle(carpeta+"entropia/resultados_entropiaZSCORE_Transponse.pickle")

# %%
dfn
# Out:
#                                                    Docs  grupo       muestreo  \
# 0     data/Only_training_hipotesis_salida/pTEST_new_...   20.0   9.csv.pickle
# 1     data/Only_training_hipotesis_salida/pTEST_new_...   20.0   9.csv.pickle
# 2     data/Only_training_hipotesis_salida/pTEST_new_...   20.0   9.csv.pickle
# 3     data/Only_training_hipotesis_salida/pTEST_new_...   20.0   9.csv.pickle
# 4     data/Only_training_hipotesis_salida/pTEST_new_...   20.0   9.csv.pickle
# ...                                                 ...    ...            ...
# 2173  data/Only_training_hipotesis_salida/pTEST_new_...   50.0  12.csv.pickle
# 2174  data/Only_training_hipotesis_salida/pTEST_new_...   50.0  12.csv.pickle
# 2175  data/Only_training_hipotesis_salida/pTEST_new_...   50.0  12.csv.pickle
# 2176  data/Only_training_hipotesis_salida/pTEST_new_...   50.0  12.csv.pickle
# 2177  data/Only_training_hipotesis_salida/pTEST_new_...   50.0  12.csv.pickle
#
#       Total  Subtotal                          E_P  \
# 0       490       443        entailment_entailment
# 1       490        38           entailment_neutral
# 2       490         9     entailment_contradiction
# 3       425        54           neutral_entailment
# 4       425       339              neutral_neutral
# ...     ...       ...                          ...
# 2173   1070       229              neutral_neutral
# 2174   1070       779        neutral_contradiction
# 2175   1111        49     contradiction_entailment
# 2176   1111       236        contradiction_neutral
# 2177   1111       826  contradiction_contradiction
#
#                                                entropia  Paraphrase
# 0     [6.813, 5.957, 6.615, 7.644, 4.949, 5.807, 6.3...           0
# 1     [7.855, 6.789, 5.322, 6.972, 6.224, 5.787, 4.7...           0
# 2     [6.305, 4.0, 4.585, 4.644, 4.755, 6.406, 4.75,...           0
# 3     [5.322, 7.018, 7.225, 6.563, 6.714, 2.676, 4.5...           0
# 4     [6.059, 6.044, 7.286, 5.322, 7.349, 6.696, 5.9...           0
# ...                                                 ...         ...
# 2173  [5.773, 5.533, 5.929, 6.596, 6.942, 5.492, 5.2...           1
# 2174  [6.533, 7.193, 6.557, 6.366, 6.322, 4.322, 5.3...           1
# 2175  [6.059, 5.189, 6.226, 6.324, 6.713, 6.228, 2.3...           1
# 2176  [6.145, 7.006, 7.365, 5.977, 4.585, 6.382, 5.2...           1
# 2177  [6.459, 5.247, 5.977, 6.501, 6.741, 7.895, 6.8...           1
#
# [2178 rows x 8 columns]

# %%
dfn=dfn.assign(relacion=dfn["Subtotal"]/dfn["Total"])
dfn
# Out:
#                                                    Docs  grupo       muestreo  \
# 0     data/Only_training_hipotesis_salida/pTEST_new_...   20.0   9.csv.pickle
# 1     data/Only_training_hipotesis_salida/pTEST_new_...   20.0   9.csv.pickle
# 2     data/Only_training_hipotesis_salida/pTEST_new_...   20.0   9.csv.pickle
# 3     data/Only_training_hipotesis_salida/pTEST_new_...   20.0   9.csv.pickle
# 4     data/Only_training_hipotesis_salida/pTEST_new_...   20.0   9.csv.pickle
# ...                                                 ...    ...            ...
# 2173  data/Only_training_hipotesis_salida/pTEST_new_...   50.0  12.csv.pickle
# 2174  data/Only_training_hipotesis_salida/pTEST_new_...   50.0  12.csv.pickle
# 2175  data/Only_training_hipotesis_salida/pTEST_new_...   50.0  12.csv.pickle
# 2176  data/Only_training_hipotesis_salida/pTEST_new_...   50.0  12.csv.pickle
# 2177  data/Only_training_hipotesis_salida/pTEST_new_...   50.0  12.csv.pickle
#
#       Total  Subtotal                          E_P  \
# 0       490       443        entailment_entailment
# 1       490        38           entailment_neutral
# 2       490         9     entailment_contradiction
# 3       425        54           neutral_entailment
# 4       425       339              neutral_neutral
# ...     ...       ...                          ...
# 2173   1070       229              neutral_neutral
# 2174   1070       779        neutral_contradiction
# 2175   1111        49     contradiction_entailment
# 2176   1111       236        contradiction_neutral
# 2177   1111       826  contradiction_contradiction
#
#                                                entropia  Paraphrase  relacion
# 0     [6.813, 5.957, 6.615, 7.644, 4.949, 5.807, 6.3...           0  0.904082
# 1     [7.855, 6.789, 5.322, 6.972, 6.224, 5.787, 4.7...           0  0.077551
# 2     [6.305, 4.0, 4.585, 4.644, 4.755, 6.406, 4.75,...           0  0.018367
# 3     [5.322, 7.018, 7.225, 6.563, 6.714, 2.676, 4.5...           0  0.127059
# 4     [6.059, 6.044, 7.286, 5.322, 7.349, 6.696, 5.9...           0  0.797647
# ...                                                 ...         ...       ...
# 2173  [5.773, 5.533, 5.929, 6.596, 6.942, 5.492, 5.2...           1  0.214019
# 2174  [6.533, 7.193, 6.557, 6.366, 6.322, 4.322, 5.3...           1  0.728037
# 2175  [6.059, 5.189, 6.226, 6.324, 6.713, 6.228, 2.3...           1  0.044104
# 2176  [6.145, 7.006, 7.365, 5.977, 4.585, 6.382, 5.2...           1  0.212421
# 2177  [6.459, 5.247, 5.977, 6.501, 6.741, 7.895, 6.8...           1  0.743474
#
# [2178 rows x 9 columns]

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
dfn_5=dfn[dfn["grupo"]==5.0]
dfn_10=dfn[dfn["grupo"]==10.0]
dfn_15=dfn[dfn["grupo"]==15.0]
dfn_20=dfn[dfn["grupo"]==20.0]
dfn_50=dfn[dfn["grupo"]==50.0]
dfn_80=dfn[dfn["grupo"]==80.0]
dfn_100=dfn[dfn["grupo"]==100.0]

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn_5,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn_15,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn_50,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn_100,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
dfn0=dfn[dfn["Paraphrase"]==0]
dfn1=dfn[dfn["Paraphrase"]==1]

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn0,x="grupo",y="relacion", hue="E_P")
# Out:
# <AxesSubplot:xlabel='grupo', ylabel='relacion'>

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn1,x="grupo",y="relacion", hue="E_P")
# Out:
# <AxesSubplot:xlabel='grupo', ylabel='relacion'>

# %% [markdown]
# ## Los anteriores resultados muestran que en cada muestreo hay una gran diferencia de los aciertos vs los errores.
# ## Con la paráfrasis se obtiene un incremento en la predicción de contradiction, pero con este modelo se obtiene más errores entre los entailment_entailment y neutral_neutral
# ## En otras palabras, el texo paráfraseado mueve los valores de la predicción hacia la contradición de la inferencia. Así para todas las predicciones.
