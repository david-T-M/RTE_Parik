# %%
import pandas as pd
import numpy as np
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
carpeta="data/training_textos_hipotesis_salida/"

# %%
dfn=pd.read_pickle(carpeta+"entropia/resultados_entropiaZSCORE_Transponse.pickle")

# %%
dfn
# Out:
#                                                    Docs  grupo       muestreo  \
# 0     data/training_textos_hipotesis_salida/pTEST_ne...   20.0   9.csv.pickle
# 1     data/training_textos_hipotesis_salida/pTEST_ne...   20.0   9.csv.pickle
# 2     data/training_textos_hipotesis_salida/pTEST_ne...   20.0   9.csv.pickle
# 3     data/training_textos_hipotesis_salida/pTEST_ne...   20.0   9.csv.pickle
# 4     data/training_textos_hipotesis_salida/pTEST_ne...   20.0   9.csv.pickle
# ...                                                 ...    ...            ...
# 2173  data/training_textos_hipotesis_salida/pTEST_ne...   50.0  12.csv.pickle
# 2174  data/training_textos_hipotesis_salida/pTEST_ne...   50.0  12.csv.pickle
# 2175  data/training_textos_hipotesis_salida/pTEST_ne...   50.0  12.csv.pickle
# 2176  data/training_textos_hipotesis_salida/pTEST_ne...   50.0  12.csv.pickle
# 2177  data/training_textos_hipotesis_salida/pTEST_ne...   50.0  12.csv.pickle
#
#       Total  Subtotal                          E_P  \
# 0       497       444        entailment_entailment
# 1       497        41           entailment_neutral
# 2       497        12     entailment_contradiction
# 3       466        55           neutral_entailment
# 4       466       372              neutral_neutral
# ...     ...       ...                          ...
# 2173   1151       240              neutral_neutral
# 2174   1151       849        neutral_contradiction
# 2175   1200        56     contradiction_entailment
# 2176   1200       244        contradiction_neutral
# 2177   1200       900  contradiction_contradiction
#
#                                                entropia  Paraphrase
# 0     [6.515, 5.374, 5.459, 7.189, 5.17, 5.643, 5.50...           0
# 1     [6.59, 5.533, 6.379, 6.418, 7.978, 5.557, 5.83...           0
# 2     [5.755, 4.75, 5.322, 5.27, 6.437, 6.465, 6.061...           0
# 3     [6.798, 5.533, 4.907, 7.245, 6.431, 5.114, 6.5...           0
# 4     [6.508, 5.984, 7.156, 6.755, 6.249, 5.975, 6.3...           0
# ...                                                 ...         ...
# 2173  [5.468, 7.233, 4.725, 7.192, 5.838, 5.129, 5.7...           1
# 2174  [7.093, 6.85, 6.557, 4.844, 5.27, 6.249, 6.07,...           1
# 2175  [4.807, 5.533, 6.344, 6.98, 6.226, 5.322, 6.71...           1
# 2176  [5.809, 6.072, 6.777, 7.374, 5.7, 7.248, 7.192...           1
# 2177  [5.74, 5.533, 5.807, 6.596, 5.799, 6.332, 6.55...           1
#
# [2178 rows x 8 columns]

# %%
dfn=dfn.assign(relacion=dfn["Subtotal"]/dfn["Total"])
dfn
# Out:
#                                                    Docs  grupo       muestreo  \
# 0     data/training_textos_hipotesis_salida/pTEST_ne...   20.0   9.csv.pickle
# 1     data/training_textos_hipotesis_salida/pTEST_ne...   20.0   9.csv.pickle
# 2     data/training_textos_hipotesis_salida/pTEST_ne...   20.0   9.csv.pickle
# 3     data/training_textos_hipotesis_salida/pTEST_ne...   20.0   9.csv.pickle
# 4     data/training_textos_hipotesis_salida/pTEST_ne...   20.0   9.csv.pickle
# ...                                                 ...    ...            ...
# 2173  data/training_textos_hipotesis_salida/pTEST_ne...   50.0  12.csv.pickle
# 2174  data/training_textos_hipotesis_salida/pTEST_ne...   50.0  12.csv.pickle
# 2175  data/training_textos_hipotesis_salida/pTEST_ne...   50.0  12.csv.pickle
# 2176  data/training_textos_hipotesis_salida/pTEST_ne...   50.0  12.csv.pickle
# 2177  data/training_textos_hipotesis_salida/pTEST_ne...   50.0  12.csv.pickle
#
#       Total  Subtotal                          E_P  \
# 0       497       444        entailment_entailment
# 1       497        41           entailment_neutral
# 2       497        12     entailment_contradiction
# 3       466        55           neutral_entailment
# 4       466       372              neutral_neutral
# ...     ...       ...                          ...
# 2173   1151       240              neutral_neutral
# 2174   1151       849        neutral_contradiction
# 2175   1200        56     contradiction_entailment
# 2176   1200       244        contradiction_neutral
# 2177   1200       900  contradiction_contradiction
#
#                                                entropia  Paraphrase  relacion
# 0     [6.515, 5.374, 5.459, 7.189, 5.17, 5.643, 5.50...           0  0.893360
# 1     [6.59, 5.533, 6.379, 6.418, 7.978, 5.557, 5.83...           0  0.082495
# 2     [5.755, 4.75, 5.322, 5.27, 6.437, 6.465, 6.061...           0  0.024145
# 3     [6.798, 5.533, 4.907, 7.245, 6.431, 5.114, 6.5...           0  0.118026
# 4     [6.508, 5.984, 7.156, 6.755, 6.249, 5.975, 6.3...           0  0.798283
# ...                                                 ...         ...       ...
# 2173  [5.468, 7.233, 4.725, 7.192, 5.838, 5.129, 5.7...           1  0.208514
# 2174  [7.093, 6.85, 6.557, 4.844, 5.27, 6.249, 6.07,...           1  0.737619
# 2175  [4.807, 5.533, 6.344, 6.98, 6.226, 5.322, 6.71...           1  0.046667
# 2176  [5.809, 6.072, 6.777, 7.374, 5.7, 7.248, 7.192...           1  0.203333
# 2177  [5.74, 5.533, 5.807, 6.596, 5.799, 6.332, 6.55...           1  0.750000
#
# [2178 rows x 9 columns]

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
dfn_5=dfn[dfn["grupo"]==5.0]
dfn_10=dfn[dfn["grupo"]==10.0]
dfn_15=dfn[dfn["grupo"]==15.0]
dfn_20=dfn[dfn["grupo"]==20.0]
dfn_50=dfn[dfn["grupo"]==50.0]
dfn_80=dfn[dfn["grupo"]==80.0]
dfn_100=dfn[dfn["grupo"]==100.0]

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn_5,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn_15,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn_50,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn_100,x="E_P",y="relacion", hue="Paraphrase")
# Out:
# <AxesSubplot:xlabel='E_P', ylabel='relacion'>

# %%
dfn0=dfn[dfn["Paraphrase"]==0]
dfn1=dfn[dfn["Paraphrase"]==1]

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn0,x="grupo",y="relacion", hue="E_P")
# Out:
# <AxesSubplot:xlabel='grupo', ylabel='relacion'>

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.barplot(data=dfn1,x="grupo",y="relacion", hue="E_P")
# Out:
# <AxesSubplot:xlabel='grupo', ylabel='relacion'>

# %% [markdown]
# ## Los anteriores resultados muestran que en cada muestreo hay una gran diferencia de los aciertos vs los errores.
# ## Con la paráfrasis se obtiene un incremento en la predicción de contradiction, pero con este modelo se obtiene más errores entre los entailment_entailment y neutral_neutral
# ## En otras palabras, el texo paráfraseado mueve los valores de la predicción hacia la contradición de la inferencia. Así para todas las predicciones.
