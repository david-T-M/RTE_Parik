# %%
import pandas as pd
import numpy as np
import glob
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
print(pd.__version__)
# Out:
# 1.4.4

# %% [markdown]
# ## Abrir los pickles obtenidos con las siguientes columnas
# ### Main index - Hace referencia al índice del ejemplo de ese corpus TEST
# ### Text - Hace referencia a los tokens usados para el Texto (Se añade NULL al principio para el procesamiento)
# ### Hipótesis - Hace referencia a los tokens usados para la Hipótesis (Se añade NULL al principio para el procesamiento)
# ### R_Text - Hace referencia a los embeddings de los tokens usados para el Texto (Se añade NULL al principio para el procesamiento)
# ### R_Hip - Hace referencia a los embeddings de los tokens usados para la Hipótesis (Se añade NULL al principio para el procesamiento)
# ### M_Align - Hace referencia a la matriz de alineamiento de los tokens del Texto y de la Hipótesis
# ### Prediction - Hace referencia a la predicción del modelo para ese ejemplo
# ### Gol_label - Etiqueta correcta del ejemplo
# ### Idx - Número de ejemplo, el primero es el real y los deḿas son con la hipótesis parafraseada

# %%
def mayorEtiqueta(a,b,c):
    if a > b and a > c:
        return 'entailment'
    elif c > a and c > b:
        return 'contradiction'
    else:
        return 'neutral'

# %%
carpeta="data/training_textos_hipotesis_salida/"

# %%
a=glob.glob(carpeta+'p*.pickle')
a[0]
# Out:
# 'data/training_textos_hipotesis_salida\\pTEST_new_0.05_0.csv.pickle'

# %%
dasdas =pd.read_pickle(a[0])
dasdas
# Out:
#      Main index                                               Text  \
# 0             0  [NULL{null,PROPN}, a{a,DET}, frowning{frown,VE...
# 1             1  [NULL{null,ADJ}, tourists{tourist,NOUN}, waiti...
# 2             2  [NULL{null,ADJ}, two{two,NUM}, people{people,N...
# 3             3  [NULL{null,PROPN}, a{a,DET}, crowd{crowd,NOUN}...
# 4             4  [NULL{null,PROPN}, a{a,DET}, little{little,ADJ...
# ..          ...                                                ...
# 723         723  [NULL{null,ADJ}, two{two,NUM}, ladies{lady,NOU...
# 724         724  [NULL{null,ADJ}, two{two,NUM}, men{man,NOUN}, ...
# 725         725  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, wi...
# 726         726  [NULL{null,PROPN}, a{a,DET}, female{female,ADJ...
# 727         727  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, in...
#
#                                              Hipotesis  \
# 0    [NULL{null,PROPN}, a{a,DET}, group{group,NOUN}...
# 1    [NULL{null,ADJ}, people{people,NOUN}, standing...
# 2    [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, an...
# 3    [NULL{null,PROPN}, a{a,DET}, crowd{crowd,NOUN}...
# 4    [NULL{null,PROPN}, the{the,DET}, little{little...
# ..                                                 ...
# 723  [NULL{null,PROPN}, the{the,DET}, birds{bird,NO...
# 724  [NULL{null,ADJ}, two{two,NUM}, friends{friend,...
# 725  [NULL{null,PROPN}, a{a,DET}, restaurant{restau...
# 726  [NULL{null,PROPN}, the{the,DET}, two{two,NUM},...
# 727  [NULL{null,ADJ}, there{there,ADV}, is{be,VERB}...
#
#                                                 R_Text  \
# 0    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 1    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 3    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 4    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# ..                                                 ...
# 723  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 724  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 725  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 726  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 727  [[0.016082555, 0.077160776, -0.013421837, 0.00...
#
#                                                  R_Hip  \
# 0    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 1    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 3    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 4    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# ..                                                 ...
# 723  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 724  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 725  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 726  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 727  [[0.016082555, 0.077160776, -0.013421837, 0.00...
#
#                                                M_Align  \
# 0    [[0.085589595, 0.014024382, 0.10871399, 0.0196...
# 1    [[0.085589595, 0.16620766, 0.09413113, 0.18659...
# 2    [[0.085589595, 0.014024382, 0.1707767, 0.00738...
# 3    [[0.085589595, 0.014024382, 0.15644503, 0.0196...
# 4    [[0.085589595, 0.004343943, 0.13497654, 0.1816...
# ..                                                 ...
# 723  [[0.085589595, 0.004343943, 0.2852142, 0.02498...
# 724  [[0.085589595, 0.08687423, 0.17640598, 0.17841...
# 725  [[0.085589595, 0.014024382, 0.2086042, 0.0, 0....
# 726  [[0.085589595, 0.004343943, 0.08687423, 0.1710...
# 727  [[0.085589595, 0.18873432, 0.016168319, 0.0140...
#
#                                   Prediction       Gold_label  Paraphrase  \
# 0    [0.97138983, 0.026692973, 0.0019171392]  [1.0, 0.0, 0.0]           0
# 1       [0.8199418, 0.16746196, 0.012596287]  [1.0, 0.0, 0.0]           0
# 2      [0.002868821, 0.93186873, 0.06526244]  [0.0, 1.0, 0.0]           0
# 3      [0.96746576, 0.0309973, 0.0015370593]  [1.0, 0.0, 0.0]           0
# 4       [0.019083902, 0.9654354, 0.01548073]  [0.0, 1.0, 0.0]           0
# ..                                       ...              ...         ...
# 723     [0.01942947, 0.38028893, 0.60028166]  [0.0, 0.0, 1.0]           1
# 724      [0.019961853, 0.47509316, 0.504945]  [0.0, 1.0, 0.0]           1
# 725     [0.876518, 0.12158899, 0.0018930178]  [1.0, 0.0, 0.0]           1
# 726    [0.88396055, 0.10602985, 0.010009562]  [1.0, 0.0, 0.0]           1
# 727  [3.6550173e-05, 0.003674085, 0.9962894]  [0.0, 0.0, 1.0]           1
#
#       Idx predicted_label     gold_label
# 0     269      entailment     entailment
# 1    2443      entailment     entailment
# 2    5066         neutral        neutral
# 3    1035      entailment     entailment
# 4    3808         neutral        neutral
# ..    ...             ...            ...
# 723  9629   contradiction  contradiction
# 724  9666   contradiction        neutral
# 725  9736      entailment     entailment
# 726  9809      entailment     entailment
# 727  9815   contradiction  contradiction
#
# [728 rows x 12 columns]

# %%
def entropia_f(X):
    """Devuelve el valor de entropia de una muestra de datos""" 
    probs = [np.mean(X == valor) for valor in set(X)]
    return round(np.sum(-p * np.log2(p) for p in probs), 3)

# %%
stats.zscore([[1,2,3,4],[4,3,2,1]])
# Out:
# array([[-1., -1.,  1.,  1.],
#        [ 1.,  1., -1., -1.]])

# %% [markdown]
# # Procesamiento de todos los resultados para calcular la entropia de los alineamientos

# %%
new_data = {'Docs' : [], 'grupo': [],'muestreo': [], 'Total' : [], 'Subtotal' : [], 'E_P' : [], 'entropia' : [], 'Paraphrase' : []}
etiquetas=['entailment','neutral','contradiction']
for e in a:
    df=pd.read_pickle(e)
    valores=[0,1]
    for i in valores:
        df_prediction=df[df["Paraphrase"]==i]
        for l1 in etiquetas:
            for l2 in etiquetas:
                new_data['Docs'].append(e)
                new_data['grupo'].append(float(e.split('_')[5])*100)
                new_data['muestreo'].append(e.split('_')[6])    
                subtotal=df_prediction[(df_prediction['gold_label']==l1) & (df_prediction['predicted_label']==l2)].shape[0]
                total=df_prediction[df_prediction['gold_label']==l1].shape[0]
                new_data['Total'].append(total)
                new_data['Subtotal'].append(subtotal)
                new_data['E_P'].append(l1+"_"+l2)
                temp=df_prediction[(df_prediction['gold_label']==l1) & (df_prediction['predicted_label']==l2)].copy()
                l_entropia=[]
                for index,strings in temp.iterrows():
                    t=strings[1]
                    h=strings[2]
                    matriz=strings[5]
                    matriz_c=matriz[1:len(t)-1,1:len(h)-1]
                    l_entropia.append(entropia_f(stats.zscore(matriz_c.T).flatten()))
                new_data['entropia'].append(np.array(l_entropia[:]))
                new_data['Paraphrase'].append(i)
                l_entropia.clear()
dfn=pd.DataFrame(new_data)
# Out:
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# ...
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: divide by zero encountered in log2
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\521637173.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   return round(np.sum(-p * np.log2(p) for p in probs), 3)

# %%
dfn.to_pickle(carpeta+"entropia/resultados_entropiaZSCORE_Transponse.pickle")

# %%
dfn=pd.read_pickle(carpeta+"entropia/resultados_entropiaZSCORE_Transponse.pickle")

# %%
dfn
# Out:
#                                                    Docs  grupo      muestreo  \
# 0     data/training_textos_hipotesis_salida\pTEST_ne...    5.0  0.csv.pickle
# 1     data/training_textos_hipotesis_salida\pTEST_ne...    5.0  0.csv.pickle
# 2     data/training_textos_hipotesis_salida\pTEST_ne...    5.0  0.csv.pickle
# 3     data/training_textos_hipotesis_salida\pTEST_ne...    5.0  0.csv.pickle
# 4     data/training_textos_hipotesis_salida\pTEST_ne...    5.0  0.csv.pickle
# ...                                                 ...    ...           ...
# 2173  data/training_textos_hipotesis_salida\pTEST_ne...  100.0  0.csv.pickle
# 2174  data/training_textos_hipotesis_salida\pTEST_ne...  100.0  0.csv.pickle
# 2175  data/training_textos_hipotesis_salida\pTEST_ne...  100.0  0.csv.pickle
# 2176  data/training_textos_hipotesis_salida\pTEST_ne...  100.0  0.csv.pickle
# 2177  data/training_textos_hipotesis_salida\pTEST_ne...  100.0  0.csv.pickle
#
#       Total  Subtotal                          E_P  \
# 0       110        95        entailment_entailment
# 1       110        15           entailment_neutral
# 2       110         0     entailment_contradiction
# 3       131        18           neutral_entailment
# 4       131        98              neutral_neutral
# ...     ...       ...                          ...
# 2173   2566      1975              neutral_neutral
# 2174   2566       297        neutral_contradiction
# 2175   2440       131     contradiction_entailment
# 2176   2440       291        contradiction_neutral
# 2177   2440      2018  contradiction_contradiction
#
#                                                entropia  Paraphrase
# 0     [6.896, 5.585, 5.707, 5.759, 5.17, 6.965, 5.32...           0
# 1     [5.807, 5.129, 5.469, 6.044, 6.755, 6.916, 6.1...           0
# 2                                                    []           0
# 3     [7.633, 6.17, 6.359, 5.75, 4.322, 5.794, 6.085...           0
# 4     [4.522, 6.976, 8.098, 7.564, 8.054, 6.306, 5.6...           0
# ...                                                 ...         ...
# 2173  [5.468, 6.724, 5.585, 6.766, 7.233, 4.725, 5.9...           1
# 2174  [6.059, 7.241, 6.642, 6.828, 5.107, 4.844, 6.4...           1
# 2175  [6.574, 5.755, 6.344, 6.777, 5.129, 6.385, 6.5...           1
# 2176  [6.52, 6.347, 5.91, 5.755, 5.491, 6.596, 5.884...           1
# 2177  [6.948, 5.74, 5.807, 5.907, 5.533, 5.807, 6.59...           1
#
# [2178 rows x 8 columns]

# %%
dfn_sinparafraseo=dfn[dfn["Paraphrase"]==0]
dfn_conparafraseo=dfn[dfn["Paraphrase"]==1]

# %%
len(dfn['grupo'].unique())
# Out:
# 7

# %%
etiquetas
# Out:
# ['entailment', 'neutral', 'contradiction']

# %%
labels=[]
for e1 in etiquetas:
    for e2 in etiquetas:
        labels.append(e1+"_"+e2)
labels
# Out:
# ['entailment_entailment',
#  'entailment_neutral',
#  'entailment_contradiction',
#  'neutral_entailment',
#  'neutral_neutral',
#  'neutral_contradiction',
#  'contradiction_entailment',
#  'contradiction_neutral',
#  'contradiction_contradiction']

# %%
valores_labels=[]
for el in labels:
    a=dfn[(dfn['E_P']==el) & (dfn['Paraphrase']==0)]
    b=a['entropia'].values[0]
    valores_labels.append(b)
valores_labels
# Out:
# [array([6.896, 5.585, 5.707, 5.759, 5.17 , 6.965, 5.329, 4.807, 6.127,
#         6.827, 4.585, 6.772, 4.535, 7.254, 5.322, 5.754, 6.072, 5.189,
#         6.014, 4.574, 6.106, 5.322, 6.592, 6.267, 5.6  , 7.625, 6.003,
#         6.247, 6.868, 6.857, 6.12 , 7.455, 6.657, 5.73 , 5.488, 5.585,
#         7.103, 6.821, 5.939, 7.181, 6.853, 6.664, 5.549, 4.755, 6.628,
#         6.509, 5.   , 6.249, 5.486, 7.249, 5.249, 5.044, 6.864, 4.844,
#         5.964, 5.496, 6.692, 6.022, 4.392, 5.406, 6.9  , 5.129, 4.922,
#         6.664, 6.003, 6.907, 5.76 , 6.712, 5.129, 6.264, 6.159, 5.967,
#         6.409, 6.918, 4.392, 4.322, 5.   , 6.493, 5.807, 4.802, 6.827,
#         7.182, 5.044, 5.14 , 5.507, 7.638, 6.122, 5.948, 6.459, 6.519,
#         7.18 , 5.589, 5.322, 5.856, 6.129]),
#  array([5.807, 5.129, 5.469, 6.044, 6.755, 6.916, 6.13 , 4.252, 4.345,
#         5.718, 5.594, 5.74 , 6.472, 6.214, 4.707]),
#  array([], dtype=float64),
#  array([7.633, 6.17 , 6.359, 5.75 , 4.322, 5.794, 6.085, 3.907, 6.977,
#         6.22 , 5.533, 6.344, 7.843, 6.892, 5.755, 5.929, 6.071, 6.537]),
#  array([4.522, 6.976, 8.098, 7.564, 8.054, 6.306, 5.644, 6.381, 5.755,
#         5.827, 4.907, 7.16 , 5.929, 7.32 , 5.681, 7.326, 6.392, 6.497,
#         6.834, 4.585, 5.392, 5.507, 6.786, 6.519, 7.748, 5.948, 5.522,
#         7.388, 5.746, 6.273, 5.92 , 6.669, 6.17 , 5.563, 5.533, 7.063,
#         7.426, 6.524, 6.985, 6.448, 6.619, 7.505, 6.225, 6.085, 5.585,
#         6.799, 5.393, 5.503, 7.222, 7.409, 6.469, 6.459, 5.929, 5.615,
#         6.261, 5.596, 6.834, 5.644, 6.866, 6.523, 7.29 , 6.947, 7.365,
#         6.282, 6.581, 5.407, 6.085, 7.563, 6.717, 7.303, 5.353, 7.514,
#         5.129, 4.807, 6.715, 5.615, 7.233, 7.218, 7.07 , 6.392, 6.481,
#         7.559, 6.354, 6.   , 8.215, 6.94 , 5.75 , 6.189, 7.126, 5.991,
#         5.872, 5.667, 6.335, 6.972, 5.728, 5.335, 6.47 , 7.16 ]),
#  array([7.144, 6.26 , 5.   , 5.707, 5.698, 6.282, 5.168, 5.098, 5.549,
#         5.755, 6.059, 6.872, 5.755, 5.17 , 6.937]),
#  array([6.085, 5.098, 6.247, 7.214, 5.072, 6.492, 7.332, 5.961, 5.615]),
#  array([5.708, 5.807, 6.148, 5.672, 6.34 , 7.023, 5.667, 5.492, 8.024,
#         8.328, 7.077, 6.955]),
#  array([5.329, 6.688, 6.837, 4.807, 6.011, 6.886, 5.986, 5.503, 6.381,
#         7.772, 6.136, 5.444, 5.948, 6.664, 5.992, 7.471, 7.029, 5.17 ,
#         6.186, 6.267, 7.144, 7.016, 6.859, 6.737, 6.267, 6.437, 5.948,
#         6.46 , 4.774, 6.129, 6.547, 6.249, 5.774, 7.226, 5.669, 5.522,
#         5.653, 6.786, 5.67 , 5.027, 6.363, 6.615, 5.044, 6.508, 6.34 ,
#         4.17 , 6.085, 5.903, 5.432, 6.205, 5.939, 6.229, 6.659, 5.91 ,
#         5.227, 6.129, 6.267, 6.278, 5.335, 7.214, 6.244, 6.749, 7.512,
#         6.059, 5.392, 5.589, 6.517, 6.329, 5.213, 6.022, 6.044, 6.492,
#         4.335, 6.136, 7.046, 5.807, 4.533, 5.492, 2.412, 6.444, 6.807,
#         4.585, 5.975, 5.322, 6.174, 6.297, 5.978, 5.585, 6.17 , 6.278,
#         6.948, 6.132, 5.5  ,   nan, 5.774, 5.189, 5.492, 6.   , 5.349,
#         6.393, 6.359, 6.053])]

# %%
len(valores_labels)
# Out:
# 9

# %%
fig2 = plt.figure(figsize=(20,10))
sns.boxplot(data=valores_labels)
plt.grid()
plt.xticks(range(9),labels,rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x2071a5395e0>,
#   <matplotlib.axis.XTick at 0x2071a539610>,
#   <matplotlib.axis.XTick at 0x207b2e7c2e0>,
#   <matplotlib.axis.XTick at 0x2072dc38250>,
#   <matplotlib.axis.XTick at 0x2072dc389a0>,
#   <matplotlib.axis.XTick at 0x2072dc38610>,
#   <matplotlib.axis.XTick at 0x2072dc47250>,
#   <matplotlib.axis.XTick at 0x2072dc479a0>,
#   <matplotlib.axis.XTick at 0x2072dc39130>],
#  [Text(0, 0, 'entailment_entailment'),
#   Text(1, 0, 'entailment_neutral'),
#   Text(2, 0, 'entailment_contradiction'),
#   Text(3, 0, 'neutral_entailment'),
#   Text(4, 0, 'neutral_neutral'),
#   Text(5, 0, 'neutral_contradiction'),
#   Text(6, 0, 'contradiction_entailment'),
#   Text(7, 0, 'contradiction_neutral'),
#   Text(8, 0, 'contradiction_contradiction')])

# %% [markdown]
# # Procesamiento para generar boxplot por muestreos

# %%
l_grupos=dfn.grupo.unique()
labels_g=[]
datos_g=[]
grupo_g=[]
for lg in l_grupos:
    for lab in labels:
        l_mean_entropia=[]
        temp=dfn[(dfn['grupo']==lg) & (dfn['E_P']==lab) & (dfn['Paraphrase']==0)]
        for index,strings in temp.iterrows():
            l_mean_entropia.append(np.nanmean(strings['entropia']))
        labels_g.append(lab)
        datos_g.append(l_mean_entropia[:])
        l_mean_entropia.clear()
        grupo_g.append(lg)
# Out:
# C:\Users\Ninja\AppData\Local\Temp\ipykernel_20540\654303805.py:10: RuntimeWarning: Mean of empty slice
#   l_mean_entropia.append(np.nanmean(strings['entropia']))

# %%
len(grupo_g)
# Out:
# 63

# %%
fig2 = plt.figure(figsize=(20,10))
ax = fig2.add_axes([-1,1,1,1])
ax.tick_params(labelsize=20)
ax.grid(visible=True)
plt.title("MEAN entropy grupo 100%",fontsize=30)
bp0 = sns.boxplot(data=datos_g[:9],linewidth=5,palette="Oranges")
ax.set_xticklabels(labels_g[:9],fontsize=20,rotation=90)
# Out:
# [Text(0, 0, 'entailment_entailment'),
#  Text(1, 0, 'entailment_neutral'),
#  Text(2, 0, 'entailment_contradiction'),
#  Text(3, 0, 'neutral_entailment'),
#  Text(4, 0, 'neutral_neutral'),
#  Text(5, 0, 'neutral_contradiction'),
#  Text(6, 0, 'contradiction_entailment'),
#  Text(7, 0, 'contradiction_neutral'),
#  Text(8, 0, 'contradiction_contradiction')]

# %%
fig2 = plt.figure(figsize=(20,10))
ax = fig2.add_axes([-1,1,1,1])
ax.tick_params(labelsize=20)
ax.grid(visible=True)
plt.title("MEAN entropy grupo 10%",fontsize=30)
bp0 = sns.boxplot(data=datos_g[9:18],linewidth=5,palette="Oranges")
ax.set_xticklabels(labels_g[9:18],fontsize=20,rotation=90)
# Out:
# [Text(0, 0, 'entailment_entailment'),
#  Text(1, 0, 'entailment_neutral'),
#  Text(2, 0, 'entailment_contradiction'),
#  Text(3, 0, 'neutral_entailment'),
#  Text(4, 0, 'neutral_neutral'),
#  Text(5, 0, 'neutral_contradiction'),
#  Text(6, 0, 'contradiction_entailment'),
#  Text(7, 0, 'contradiction_neutral'),
#  Text(8, 0, 'contradiction_contradiction')]

# %%
fig2 = plt.figure(figsize=(20,10))
ax = fig2.add_axes([-1,1,1,1])
ax.tick_params(labelsize=20)
ax.grid(visible=True)
plt.title("MEAN entropy grupo 20%",fontsize=30)
bp0 = sns.boxplot(data=datos_g[18:27],linewidth=5,palette="Oranges")
ax.set_xticklabels(labels_g[18:27],fontsize=20,rotation=90)
# Out:
# [Text(0, 0, 'entailment_entailment'),
#  Text(1, 0, 'entailment_neutral'),
#  Text(2, 0, 'entailment_contradiction'),
#  Text(3, 0, 'neutral_entailment'),
#  Text(4, 0, 'neutral_neutral'),
#  Text(5, 0, 'neutral_contradiction'),
#  Text(6, 0, 'contradiction_entailment'),
#  Text(7, 0, 'contradiction_neutral'),
#  Text(8, 0, 'contradiction_contradiction')]

# %%
fig2 = plt.figure(figsize=(20,10))
ax = fig2.add_axes([-1,1,1,1])
ax.tick_params(labelsize=20)
ax.grid(visible=True)
plt.title("MEAN entropy grupo 80%",fontsize=30)
bp0 = sns.boxplot(data=datos_g[27:36],linewidth=5,palette="Oranges")
ax.set_xticklabels(labels_g[27:36],fontsize=20,rotation=90)
# Out:
# [Text(0, 0, 'entailment_entailment'),
#  Text(1, 0, 'entailment_neutral'),
#  Text(2, 0, 'entailment_contradiction'),
#  Text(3, 0, 'neutral_entailment'),
#  Text(4, 0, 'neutral_neutral'),
#  Text(5, 0, 'neutral_contradiction'),
#  Text(6, 0, 'contradiction_entailment'),
#  Text(7, 0, 'contradiction_neutral'),
#  Text(8, 0, 'contradiction_contradiction')]

# %%
fig2 = plt.figure(figsize=(20,10))
ax = fig2.add_axes([-1,1,1,1])
ax.tick_params(labelsize=20)
ax.grid(visible=True)
plt.title("MEAN entropy grupo 15%",fontsize=30)
bp0 = sns.boxplot(data=datos_g[36:45],linewidth=5,palette="Oranges")
ax.set_xticklabels(labels_g[36:45],fontsize=20,rotation=90)
# Out:
# [Text(0, 0, 'entailment_entailment'),
#  Text(1, 0, 'entailment_neutral'),
#  Text(2, 0, 'entailment_contradiction'),
#  Text(3, 0, 'neutral_entailment'),
#  Text(4, 0, 'neutral_neutral'),
#  Text(5, 0, 'neutral_contradiction'),
#  Text(6, 0, 'contradiction_entailment'),
#  Text(7, 0, 'contradiction_neutral'),
#  Text(8, 0, 'contradiction_contradiction')]

# %%
fig2 = plt.figure(figsize=(20,10))
ax = fig2.add_axes([-1,1,1,1])
ax.tick_params(labelsize=20)
ax.grid(visible=True)
plt.title("MEAN entropy grupo 5%",fontsize=30)
bp0 = sns.boxplot(data=datos_g[45:54],linewidth=5,palette="Oranges")
ax.set_xticklabels(labels_g[45:54],fontsize=20,rotation=90)
# Out:
# [Text(0, 0, 'entailment_entailment'),
#  Text(1, 0, 'entailment_neutral'),
#  Text(2, 0, 'entailment_contradiction'),
#  Text(3, 0, 'neutral_entailment'),
#  Text(4, 0, 'neutral_neutral'),
#  Text(5, 0, 'neutral_contradiction'),
#  Text(6, 0, 'contradiction_entailment'),
#  Text(7, 0, 'contradiction_neutral'),
#  Text(8, 0, 'contradiction_contradiction')]

# %%
fig2 = plt.figure(figsize=(20,10))
ax = fig2.add_axes([-1,1,1,1])
ax.tick_params(labelsize=20)
ax.grid(visible=True)
plt.title("MEAN entropy grupo 50%",fontsize=30)
bp0 = sns.boxplot(data=datos_g[54:63],linewidth=5,palette="Oranges")
ax.set_xticklabels(labels_g[54:63],fontsize=20,rotation=90)
# Out:
# [Text(0, 0, 'entailment_entailment'),
#  Text(1, 0, 'entailment_neutral'),
#  Text(2, 0, 'entailment_contradiction'),
#  Text(3, 0, 'neutral_entailment'),
#  Text(4, 0, 'neutral_neutral'),
#  Text(5, 0, 'neutral_contradiction'),
#  Text(6, 0, 'contradiction_entailment'),
#  Text(7, 0, 'contradiction_neutral'),
#  Text(8, 0, 'contradiction_contradiction')]

# %% [markdown]
# # Matriz de alineamiento

# %%
a=glob.glob(carpeta+'p*.pickle')
a[0]
# Out:
# 'data/training_textos_hipotesis_salida\\pTEST_new_0.05_0.csv.pickle'

# %%
df=pd.read_pickle(a[0])
df
# Out:
#      Main index                                               Text  \
# 0             0  [NULL{null,PROPN}, a{a,DET}, frowning{frown,VE...
# 1             1  [NULL{null,ADJ}, tourists{tourist,NOUN}, waiti...
# 2             2  [NULL{null,ADJ}, two{two,NUM}, people{people,N...
# 3             3  [NULL{null,PROPN}, a{a,DET}, crowd{crowd,NOUN}...
# 4             4  [NULL{null,PROPN}, a{a,DET}, little{little,ADJ...
# ..          ...                                                ...
# 723         723  [NULL{null,ADJ}, two{two,NUM}, ladies{lady,NOU...
# 724         724  [NULL{null,ADJ}, two{two,NUM}, men{man,NOUN}, ...
# 725         725  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, wi...
# 726         726  [NULL{null,PROPN}, a{a,DET}, female{female,ADJ...
# 727         727  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, in...
#
#                                              Hipotesis  \
# 0    [NULL{null,PROPN}, a{a,DET}, group{group,NOUN}...
# 1    [NULL{null,ADJ}, people{people,NOUN}, standing...
# 2    [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, an...
# 3    [NULL{null,PROPN}, a{a,DET}, crowd{crowd,NOUN}...
# 4    [NULL{null,PROPN}, the{the,DET}, little{little...
# ..                                                 ...
# 723  [NULL{null,PROPN}, the{the,DET}, birds{bird,NO...
# 724  [NULL{null,ADJ}, two{two,NUM}, friends{friend,...
# 725  [NULL{null,PROPN}, a{a,DET}, restaurant{restau...
# 726  [NULL{null,PROPN}, the{the,DET}, two{two,NUM},...
# 727  [NULL{null,ADJ}, there{there,ADV}, is{be,VERB}...
#
#                                                 R_Text  \
# 0    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 1    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 3    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 4    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# ..                                                 ...
# 723  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 724  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 725  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 726  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 727  [[0.016082555, 0.077160776, -0.013421837, 0.00...
#
#                                                  R_Hip  \
# 0    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 1    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 2    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 3    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 4    [[0.016082555, 0.077160776, -0.013421837, 0.00...
# ..                                                 ...
# 723  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 724  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 725  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 726  [[0.016082555, 0.077160776, -0.013421837, 0.00...
# 727  [[0.016082555, 0.077160776, -0.013421837, 0.00...
#
#                                                M_Align  \
# 0    [[0.085589595, 0.014024382, 0.10871399, 0.0196...
# 1    [[0.085589595, 0.16620766, 0.09413113, 0.18659...
# 2    [[0.085589595, 0.014024382, 0.1707767, 0.00738...
# 3    [[0.085589595, 0.014024382, 0.15644503, 0.0196...
# 4    [[0.085589595, 0.004343943, 0.13497654, 0.1816...
# ..                                                 ...
# 723  [[0.085589595, 0.004343943, 0.2852142, 0.02498...
# 724  [[0.085589595, 0.08687423, 0.17640598, 0.17841...
# 725  [[0.085589595, 0.014024382, 0.2086042, 0.0, 0....
# 726  [[0.085589595, 0.004343943, 0.08687423, 0.1710...
# 727  [[0.085589595, 0.18873432, 0.016168319, 0.0140...
#
#                                   Prediction       Gold_label  Paraphrase  \
# 0    [0.97138983, 0.026692973, 0.0019171392]  [1.0, 0.0, 0.0]           0
# 1       [0.8199418, 0.16746196, 0.012596287]  [1.0, 0.0, 0.0]           0
# 2      [0.002868821, 0.93186873, 0.06526244]  [0.0, 1.0, 0.0]           0
# 3      [0.96746576, 0.0309973, 0.0015370593]  [1.0, 0.0, 0.0]           0
# 4       [0.019083902, 0.9654354, 0.01548073]  [0.0, 1.0, 0.0]           0
# ..                                       ...              ...         ...
# 723     [0.01942947, 0.38028893, 0.60028166]  [0.0, 0.0, 1.0]           1
# 724      [0.019961853, 0.47509316, 0.504945]  [0.0, 1.0, 0.0]           1
# 725     [0.876518, 0.12158899, 0.0018930178]  [1.0, 0.0, 0.0]           1
# 726    [0.88396055, 0.10602985, 0.010009562]  [1.0, 0.0, 0.0]           1
# 727  [3.6550173e-05, 0.003674085, 0.9962894]  [0.0, 0.0, 1.0]           1
#
#       Idx predicted_label     gold_label
# 0     269      entailment     entailment
# 1    2443      entailment     entailment
# 2    5066         neutral        neutral
# 3    1035      entailment     entailment
# 4    3808         neutral        neutral
# ..    ...             ...            ...
# 723  9629   contradiction  contradiction
# 724  9666   contradiction        neutral
# 725  9736      entailment     entailment
# 726  9809      entailment     entailment
# 727  9815   contradiction  contradiction
#
# [728 rows x 12 columns]

# %%
pos=['DET','AUX','NOUN','PROPN','CONJ','VERB','ADP','ADV','NUM','ADJ']

# %%
new_data = {'Docs' : [], 'grupo': [], 'grupo': []}
for e in a[:1]:
    df=pd.read_pickle(e)
    t=df.Text[1]
    h=df.Hipotesis[1]
    matriz=df.M_Align[1]
    matriz_c=matriz[1:len(t)-1,1:len(h)-1]
    p1_df1=pd.DataFrame(matriz_c,columns=h[1:-1],index=t[1:-1])
    m=p1_df1>0.05
    c_a=m.columns
    data=pd.DataFrame(0.0,columns=pos,index=pos)
    for i,strings in m.iterrows():
        for j in range(len(c_a)):
            if(strings[j]==True):
                #print(i,c_a[j])
                #print(i.split(',')[1][:-1],c_a[j].split(',')[1][:-1])
                data.at[i.split(',')[1][:-1],c_a[j].split(',')[1][:-1]]+=1
    df.assign(mapas_p=data)
    df.to_pickle(e)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Ninja\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\Users\Ninja\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\Ninja\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PART'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20540\3261528916.py in <module>
#      15                 #print(i,c_a[j])
#      16                 #print(i.split(',')[1][:-1],c_a[j].split(',')[1][:-1])
# ---> 17                 data.at[i.split(',')[1][:-1],c_a[j].split(',')[1][:-1]]+=1
#      18     df.assign(mapas_p=data)
#      19     df.to_pickle(e)
#
# c:\Users\Ninja\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2273             return self.obj.loc[key]
#    2274
# -> 2275         return super().__getitem__(key)
#    2276
#    2277     def __setitem__(self, key, value):
#
# c:\Users\Ninja\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2224
#    2225         key = self._convert_key(key)
# -> 2226         return self.obj._get_value(*key, takeable=self._takeable)
#    2227
#    2228     def __setitem__(self, key, value):
#
# c:\Users\Ninja\anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    3620             #  results if our categories are integers that dont match our codes
#    3621             # IntervalIndex: IntervalTree has no get_loc
# -> 3622             row = self.index.get_loc(index)
#    3623             return series._values[row]
#    3624
#
# c:\Users\Ninja\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'PART'

# %%
p1_df1
# Out:
#                       a{a,DET}  girl{girl,NOUN}  standing{stand,VERB}  \
# a{a,DET}              0.026112         0.032301              0.002110
# young{young,ADJ}      0.012644         2.421997              0.144034
# girl{girl,NOUN}       0.032301         4.757977              0.013298
# wearing{wear,VERB}    0.004252         0.430328              0.272805
# a{a,DET}              0.026112         0.032301              0.002110
# blue{blue,ADJ}        0.003186         0.616689              0.842984
# ski{ski,NOUN}         0.040288         1.772164              0.590751
# cap{cap,NOUN}         0.021523         0.788131              0.787639
# and{and,CCONJ}        0.008232         0.019073              0.074781
# red{red,ADJ}          0.001293         0.899974              0.595683
# and{and,CCONJ}        0.008232         0.019073              0.074781
# gray{gray,ADJ}        0.004947         0.507965              0.570346
# two{two,NUM}          0.027860         0.559040              0.163078
# tone{tone,NOUN}       0.071818         0.348233              0.606280
# jacket{jacket,NOUN}   0.005075         0.604215              0.499027
# stands{stand,VERB}    0.001375         0.006513              3.638041
# between{between,ADP}  0.041171         0.180855              0.309037
# two{two,NUM}          0.027860         0.559040              0.163078
# bits{bit,NOUN}        0.048517         0.216791              0.433087
# of{of,ADP}            0.016250         0.080763              0.009767
# ice{ice,NOUN}         0.036414         0.376732              0.471762
#
#                       near{near,ADP}  ice{ice,NOUN}
# a{a,DET}                    0.032530       0.036414
# young{young,ADJ}            0.089389       0.137721
# girl{girl,NOUN}             0.230694       0.376732
# wearing{wear,VERB}          0.105045       0.461938
# a{a,DET}                    0.032530       0.036414
# blue{blue,ADJ}              0.185570       0.936239
# ski{ski,NOUN}               0.602710       2.755061
# cap{cap,NOUN}               0.203158       1.162597
# and{and,CCONJ}              0.052327       0.005008
# red{red,ADJ}                0.137226       1.137786
# and{and,CCONJ}              0.052327       0.005008
# gray{gray,ADJ}              0.212511       0.798157
# two{two,NUM}                0.015623       0.040227
# tone{tone,NOUN}             0.310949       0.783246
# jacket{jacket,NOUN}         0.216991       1.079117
# stands{stand,VERB}          0.704352       0.422279
# between{between,ADP}        0.571894       0.430873
# two{two,NUM}                0.015623       0.040227
# bits{bit,NOUN}              0.249126       1.009987
# of{of,ADP}                  0.039430       0.039248
# ice{ice,NOUN}               0.567819       3.574654

# %%
segundo1=segundo[:len(t1[1:]),:len(h1[1:])]
segundo1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_214661/4043234114.py in <module>
# ----> 1 segundo1=segundo[:len(t1[1:]),:len(h1[1:])]
#       2 segundo1
#
# NameError: name 'segundo' is not defined

# %%
len(t1[1:-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_214661/176613593.py in <module>
# ----> 1 len(t1[1:-1])
#
# NameError: name 't1' is not defined

# %%
segundo1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_214661/1708137941.py in <module>
# ----> 1 segundo1
#
# NameError: name 'segundo1' is not defined

# %%
t1[1:-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_214661/3004354063.py in <module>
# ----> 1 t1[1:-1]
#
# NameError: name 't1' is not defined

# %%
h1[1:-1]
# Out:
# ['two{two,NUM}',
#  'girls{girl,NOUN}',
#  'eating{eat,VERB}',
#  'cupcakes{cupcake,NOUN}']

# %%
p1_df=pd.DataFrame(segundo1,columns=h1[1:-1],index=t1[1:-1])
p1_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_214661/3161406307.py in <module>
# ----> 1 p1_df=pd.DataFrame(segundo1,columns=h1[1:-1],index=t1[1:-1])
#       2 p1_df
#
# NameError: name 'segundo1' is not defined

# %%
p1_df>1.0
# Out:
#                               two{two,NUM}  girls{girl,NOUN}  \
# two{two,NUM}                         False             False
# beautiful{beautiful,ADJ}             False             False
# ,{,,PUNCT}                           False             False
# little{little,ADJ}                   False             False
# girls{girl,NOUN}                     False             False
# with{with,ADP}                       False             False
# dark{dark,ADJ}                       False             False
# hair{hair,NOUN}                      False             False
# and{and,CCONJ}                       False             False
# dark{dark,ADJ}                       False             False
# complexions{complexion,NOUN}         False             False
# are{be,VERB}                         False             False
# sitting{sit,VERB}                    False             False
# down{down,ADP}                       False             False
# eating{eat,VERB}                     False             False
# cupcakes{cupcake,NOUN}               False             False
#
#                               eating{eat,VERB}  cupcakes{cupcake,NOUN}
# two{two,NUM}                             False                   False
# beautiful{beautiful,ADJ}                 False                   False
# ,{,,PUNCT}                                True                   False
# little{little,ADJ}                       False                   False
# girls{girl,NOUN}                          True                   False
# with{with,ADP}                            True                   False
# dark{dark,ADJ}                           False                   False
# hair{hair,NOUN}                          False                   False
# and{and,CCONJ}                           False                   False
# dark{dark,ADJ}                           False                   False
# complexions{complexion,NOUN}             False                   False
# are{be,VERB}                              True                    True
# sitting{sit,VERB}                        False                   False
# down{down,ADP}                           False                    True
# eating{eat,VERB}                         False                   False
# cupcakes{cupcake,NOUN}                   False                    True

# %%
p2_df=pd.DataFrame(tercero,columns=h2,index=t2)
p2_df
# Out:
#                      NULL{null,PROPN}  the{the,DET}  young{young,ADJ}  \
# NULL{null,ADJ}               0.085590      0.004344          0.053287
# young{young,ADJ}             0.053287      0.000000          3.354251
# asian{asian,ADJ}             0.171800      0.002002          1.647641
# girl{girl,NOUN}              0.175829      0.000000          2.421997
# is{be,VERB}                  0.016168      0.000754          0.001131
# sitting{sit,VERB}            0.129529      0.014924          0.091514
# on{on,ADP}                   0.072442      0.027239          0.000000
# the{the,DET}                 0.004344      0.010587          0.000000
# ground{ground,NOUN}          0.113950      0.052529          0.014226
# in{in,ADP}                   0.035283      0.015836          0.055924
# rubble{rubble,NOUN}          0.114444      0.048821          0.325265
# .{.,PUNCT}                   0.019895      0.000569          0.000500
#
#                      asian{asian,NOUN}  has{have,VERB}  lost{lose,VERB}  \
# NULL{null,ADJ}                0.171800        0.023192         0.222093
# young{young,ADJ}              1.647641        0.001499         0.786800
# asian{asian,ADJ}              6.379494        0.038734         0.670528
# girl{girl,NOUN}               2.198625        0.022157         0.998042
# is{be,VERB}                   0.041788        0.050052         0.206750
# sitting{sit,VERB}             0.238929        0.286968         1.611974
# on{on,ADP}                    0.021870        0.105842         0.416032
# the{the,DET}                  0.002002        0.001261         0.032855
# ground{ground,NOUN}           0.326269        0.081997         0.621133
# in{in,ADP}                    0.128673        0.007425         0.080465
# rubble{rubble,NOUN}           0.726215        0.030950         1.049793
# .{.,PUNCT}                    0.060486        0.023960         0.022159
#
#                      her{-PRON-,ADJ}  home{home,NOUN}  .{.,PUNCT}
# NULL{null,ADJ}              0.123447         0.182407    0.019895
# young{young,ADJ}            1.065274         0.958108    0.000500
# asian{asian,ADJ}            0.883780         1.009200    0.060486
# girl{girl,NOUN}             2.462749         0.825765    0.016948
# is{be,VERB}                 0.017458         0.060604    0.010017
# sitting{sit,VERB}           0.113148         1.125567    0.066369
# on{on,ADP}                  0.025365         0.469023    0.057957
# the{the,DET}                0.000730         0.033216    0.000569
# ground{ground,NOUN}         0.024738         1.264447    0.035830
# in{in,ADP}                  0.064693         0.380117    0.016951
# rubble{rubble,NOUN}         0.129340         1.254742    0.023177
# .{.,PUNCT}                  0.013347         0.019007    0.032226

# %%
ppu_df=pd.DataFrame(pu,columns=h9710,index=t9710)
ppu_df
# Out:
#                            NULL{null,NOUN}  who{who,NOUN}  can{can,VERB}  \
# NULL{null,PROPN}                  0.085590       0.068495       0.040631
# a{a,DET}                          0.014024       0.034103       0.027070
# man{man,NOUN}                     0.170777       1.076692       0.156812
# in{in,ADP}                        0.035283       0.005884       0.022535
# a{a,DET}                          0.014024       0.034103       0.027070
# black{black,ADJ}                  0.144041       0.051169       0.000000
# leather{leather,NOUN}             0.200748       0.087373       0.102858
# jacket{jacket,NOUN}               0.201228       0.021783       0.095439
# and{and,CCONJ}                    0.007381       0.012460       0.012999
# a{a,DET}                          0.014024       0.034103       0.027070
# book{book,NOUN}                   0.181464       0.531111       0.147346
# in{in,ADP}                        0.035283       0.005884       0.022535
# his{-PRON-,ADJ}                   0.127242       0.764391       0.118792
# hand{hand,NOUN}                   0.113706       0.161816       0.206129
# speaks{speak,VERB}                0.213129       0.458791       0.284040
# in{in,ADP}                        0.035283       0.005884       0.022535
# a{a,DET}                          0.014024       0.034103       0.027070
# classroom{classroom,NOUN}         0.268744       0.460076       0.159426
# .{.,PUNCT}                        0.019895       0.003294       0.034779
#
#                            see{see,VERB}  if{if,ADP}  a{a,DET}  boy{boy,NOUN}  \
# NULL{null,PROPN}                0.100524    0.243695  0.014024       0.181695
# a{a,DET}                        0.046976    0.092261  0.026112       0.072897
# man{man,NOUN}                   0.253527    0.829915  0.045507       2.588851
# in{in,ADP}                      0.145067    0.158340  0.005198       0.057368
# a{a,DET}                        0.046976    0.092261  0.026112       0.072897
# black{black,ADJ}                0.048811    0.691930  0.001848       0.511577
# leather{leather,NOUN}           0.195575    0.646629  0.010482       0.098515
# jacket{jacket,NOUN}             0.141977    0.757624  0.005075       0.531325
# and{and,CCONJ}                  0.064264    0.056411  0.008232       0.037506
# a{a,DET}                        0.046976    0.092261  0.026112       0.072897
# book{book,NOUN}                 0.318049    1.052547  0.065757       0.658881
# in{in,ADP}                      0.145067    0.158340  0.005198       0.057368
# his{-PRON-,ADJ}                 0.167033    0.549477  0.052524       1.824592
# hand{hand,NOUN}                 0.294697    0.540487  0.007646       0.081531
# speaks{speak,VERB}              0.936733    1.711957  0.091470       0.800118
# in{in,ADP}                      0.145067    0.158340  0.005198       0.057368
# a{a,DET}                        0.046976    0.092261  0.026112       0.072897
# classroom{classroom,NOUN}       0.674831    1.107455  0.046417       1.278911
# .{.,PUNCT}                      0.073784    0.101690  0.007956       0.019116
#
#                            is{be,VERB}  speaking{speak,VERB}  in{in,ADP}  \
# NULL{null,PROPN}              0.016168              0.253991    0.035283
# a{a,DET}                      0.014831              0.106009    0.005198
# man{man,NOUN}                 0.054329              1.055059    0.021190
# in{in,ADP}                    0.003406              0.039731    0.152197
# a{a,DET}                      0.014831              0.106009    0.005198
# black{black,ADJ}              0.036005              0.989516    0.091512
# leather{leather,NOUN}         0.040128              1.309244    0.091997
# jacket{jacket,NOUN}           0.011618              1.122985    0.085604
# and{and,CCONJ}                0.012324              0.071158    0.006564
# a{a,DET}                      0.014831              0.106009    0.005198
# book{book,NOUN}               0.046380              2.077209    0.069795
# in{in,ADP}                    0.003406              0.039731    0.152197
# his{-PRON-,ADJ}               0.043559              0.884653    0.017155
# hand{hand,NOUN}               0.075573              1.542791    0.014168
# speaks{speak,VERB}            0.178248              3.925356    0.077466
# in{in,ADP}                    0.003406              0.039731    0.152197
# a{a,DET}                      0.014831              0.106009    0.005198
# classroom{classroom,NOUN}     0.051902              1.567753    0.473592
# .{.,PUNCT}                    0.010017              0.080807    0.016951
#
#                            the{the,DET}  classroom{classroom,NOUN}  .{.,PUNCT}
# NULL{null,PROPN}               0.004344                   0.268744    0.019895
# a{a,DET}                       0.002669                   0.046417    0.007956
# man{man,NOUN}                  0.000000                   0.631887    0.024603
# in{in,ADP}                     0.015836                   0.473592    0.016951
# a{a,DET}                       0.002669                   0.046417    0.007956
# black{black,ADJ}               0.000238                   0.955209    0.050242
# leather{leather,NOUN}          0.021863                   1.048118    0.077999
# jacket{jacket,NOUN}            0.006428                   0.725466    0.095009
# and{and,CCONJ}                 0.001435                   0.010643    0.009586
# a{a,DET}                       0.002669                   0.046417    0.007956
# book{book,NOUN}                0.015586                   2.903082    0.004655
# in{in,ADP}                     0.015836                   0.473592    0.016951
# his{-PRON-,ADJ}                0.000606                   0.662812    0.015523
# hand{hand,NOUN}                0.004673                   0.573317    0.046556
# speaks{speak,VERB}             0.010610                   1.581515    0.092217
# in{in,ADP}                     0.015836                   0.473592    0.016951
# a{a,DET}                       0.002669                   0.046417    0.007956
# classroom{classroom,NOUN}      0.038116                   5.765718    0.032285
# .{.,PUNCT}                     0.000569                   0.032285    0.032226

# %%
p_df=pd.DataFrame(p,columns=h,index=t)
p_df
# Out:
#                           NULL{null,PROPN}  the{the,DET}  people{people,NOUN}  \
# NULL{null,ADJ}                    0.085590      0.004344             0.166208
# people{people,NOUN}               0.166208      0.000175             2.102587
# standing{stand,VERB}              0.094131      0.028553             0.144738
# in{in,ADP}                        0.035283      0.015836             0.018224
# front{front,NOUN}                 0.117238      0.044911             0.097520
# of{of,ADP}                        0.019655      0.001971             0.117327
# a{a,DET}                          0.014024      0.002669             0.070605
# gray{gray,ADJ}                    0.153849      0.013272             0.369972
# building{building,NOUN}           0.095689      0.034629             0.171862
# with{with,ADP}                    0.005117      0.000000             0.029919
# a{a,DET}                          0.014024      0.002669             0.070605
# sign{sign,NOUN}                   0.207169      0.022282             0.457815
# that{that,ADJ}                    0.066778      0.005188             0.291078
# reads{read,VERB}                  0.262448      0.013826             0.858007
# '{',PUNCT}                        0.039691      0.010494             0.085555
# tickets{ticket,NOUN}              0.146056      0.027648             0.588120
# available{available,ADJ}          0.110744      0.019989             0.215672
# here{here,ADV}                    0.131814      0.017253             0.400698
# '{',PUNCT}                        0.039691      0.010494             0.085555
# .{.,PUNCT}                        0.019895      0.000569             0.031495
# 0                                 0.000000      0.000000             0.000000
#
#                           are{be,VERB}  inside{inside,ADP}  the{the,DET}  \
# NULL{null,ADJ}                0.011193            0.179063      0.004344
# people{people,NOUN}           0.052006            0.074834      0.000175
# standing{stand,VERB}          0.093257            0.727564      0.028553
# in{in,ADP}                    0.000000            0.479227      0.015836
# front{front,NOUN}             0.002686            1.645524      0.044911
# of{of,ADP}                    0.007011            0.025717      0.001971
# a{a,DET}                      0.013368            0.012248      0.002669
# gray{gray,ADJ}                0.048005            0.903849      0.013272
# building{building,NOUN}       0.001266            1.646757      0.034629
# with{with,ADP}                0.004076            0.000012      0.000000
# a{a,DET}                      0.013368            0.012248      0.002669
# sign{sign,NOUN}               0.043516            0.852319      0.022282
# that{that,ADJ}                0.016021            0.112642      0.005188
# reads{read,VERB}              0.069341            0.762527      0.013826
# '{',PUNCT}                    0.004800            0.392338      0.010494
# tickets{ticket,NOUN}          0.031170            0.860896      0.027648
# available{available,ADJ}      0.011784            0.705910      0.019989
# here{here,ADV}                0.047391            0.610873      0.017253
# '{',PUNCT}                    0.004800            0.392338      0.010494
# .{.,PUNCT}                    0.003406            0.059224      0.000569
# 0                             0.000000            0.000000      0.000000
#
#                           classroom{classroom,NOUN}  .{.,PUNCT}
# NULL{null,ADJ}                             0.268744    0.019895
# people{people,NOUN}                        0.731497    0.031495
# standing{stand,VERB}                       0.620738    0.056419
# in{in,ADP}                                 0.473592    0.016951
# front{front,NOUN}                          1.113147    0.069333
# of{of,ADP}                                 0.094611    0.003876
# a{a,DET}                                   0.046417    0.007956
# gray{gray,ADJ}                             1.047610    0.068112
# building{building,NOUN}                    2.813413    0.011337
# with{with,ADP}                             0.003272    0.004435
# a{a,DET}                                   0.046417    0.007956
# sign{sign,NOUN}                            0.907344    0.100803
# that{that,ADJ}                             0.215162    0.045922
# reads{read,VERB}                           2.101241    0.115035
# '{',PUNCT}                                 0.673350    0.009293
# tickets{ticket,NOUN}                       1.996046    0.011769
# available{available,ADJ}                   1.456300    0.012183
# here{here,ADV}                             0.898393    0.083522
# '{',PUNCT}                                 0.673350    0.009293
# .{.,PUNCT}                                 0.032285    0.032226
# 0                                          0.000000    0.000000

# %%
sns.heatmap(p_df, center=0, cmap='Blues_r', annot=True, fmt='.3f')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(p1_df, center=0, cmap='Blues_r', annot=True, fmt='.3f')
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.heatmap(p2_df, center=0, cmap='Blues_r', annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.heatmap(ppu_df, center=0, cmap='Blues_r', annot=True, fmt='.3f')
# Out:
# <AxesSubplot:>
